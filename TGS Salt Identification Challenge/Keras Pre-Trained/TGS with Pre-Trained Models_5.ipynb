# %%
import os
import sys
import random
import warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from segmentation_models import FPN
from segmentation_models.utils import set_trainable

from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

from keras.applications.resnet50 import ResNet50
from keras.models import Model, load_model
from keras.layers import Input , Concatenate
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.layers import *
from keras.initializers import he_normal
from keras.regularizers import l2
from keras.layers import Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras.optimizers import *
from keras.utils import to_categorical
from keras.losses import binary_crossentropy
import tensorflow as tf

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
im_width = 256
im_height = 256
border = 5
im_chan = 3
n_features = 1 
path_train = 'data/train/'
path_test = 'data/test/'

# %%
ids= ['1f1cc6b3a4','5b7c160d0d','6c40978ddf','7dfdf6eeb8','7e5a6e5013']
plt.figure(figsize=(20,10))
for j, img_name in enumerate(ids):
    q = j+1
    img = load_img('data/train/images/' + img_name + '.png')
    img_mask = load_img('data/train/masks/' + img_name + '.png')
    
    plt.subplot(1,2*(1+len(ids)),q*2-1)
    plt.imshow(img)
    plt.subplot(1,2*(1+len(ids)),q*2)
    plt.imshow(img_mask)
plt.show()

# %%
train_ids = next(os.walk(path_train+"images"))[2]
test_ids = next(os.walk(path_test+"images"))[2]

# %%
X_train = np.zeros((len(train_ids), im_height, im_width, im_chan), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), 256, 256 , 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
sum_whites = 0
for n, id_ in enumerate(train_ids):
    path = path_train
    img = load_img(path + '/images/' + id_)
    x = img_to_array(img)[:,:,1]
    x = resize(x, (256, 256 , 3), preserve_range=True)
    X_train[n] = x
    mask = img_to_array(load_img(path + '/masks/' + id_))[:,:,1]
    Y_train[n] = resize(mask, (256, 256, 1), preserve_range=True)
    sum_whites += np.sum(Y_train[n])

print('Done!')

print("Salt in the dataset is {}".format(sum_whites*1.0 / (X_train.shape[0] * 256*256)))
# Out:
# Getting and resizing train images and masks ...
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Done!
# Salt in the dataset is 0.24794946670532225

# %%
Y_train[0].shape
# Out:
# (256, 256, 1)

# %%
ix = random.randint(0, len(train_ids))
plt.imshow(X_train[ix])
plt.show()
tmp = np.squeeze(Y_train[ix]).astype(np.float32)
plt.imshow(np.dstack((tmp,tmp,tmp)))
plt.show()

# %%
X_train , X_val , Y_train , Y_val = train_test_split(X_train , Y_train , train_size = 0.9 , random_state = 97)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
image_generator = ImageDataGenerator(
    horizontal_flip=True,
    vertical_flip = True,
    zoom_range = 0.2,
    width_shift_range = 0.2,
    height_shift_range = 0.2
)

mask_generator = ImageDataGenerator(
    horizontal_flip=True,
    vertical_flip = True,
    zoom_range = 0.2,
    width_shift_range = 0.2,
    height_shift_range = 0.2
)

val_image_generator = ImageDataGenerator(
)
val_mask_generator = ImageDataGenerator(
)

train_img_gen = image_generator.flow(X_train , seed = 97 , batch_size = 16)
train_mask_gen = mask_generator.flow(Y_train , seed = 97 , batch_size = 16)

val_img_gen = val_image_generator.flow(X_val , seed = 97 , batch_size = 16)
val_mask_gen = val_mask_generator.flow(Y_val , seed = 97 , batch_size = 16)

# %%
train_gen = zip(train_img_gen , train_mask_gen)
val_gen = zip(val_img_gen , val_mask_gen)

# %%
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
model = FPN(backbone_name='resnet50', input_shape = (256,256,3))

# %%
# def dice_coef(y_true, y_pred):
#     y_true_f = K.flatten(y_true)
#     y_pred = K.cast(y_pred, 'float32')
#     y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
#     intersection = y_true_f * y_pred_f
#     score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
#     return score

# def dice_loss(y_true, y_pred):
#     smooth = 1.
#     y_true_f = K.flatten(y_true)
#     y_pred_f = K.flatten(y_pred)
#     intersection = y_true_f * y_pred_f
#     score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
#     return 1. - score

# def bce_dice_loss(y_true, y_pred):
#     return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# def bce_logdice_loss(y_true, y_pred):
#     return binary_crossentropy(y_true, y_pred) - K.log(1. - dice_loss(y_true, y_pred))

# def weighted_bce_loss(y_true, y_pred, weight):
#     epsilon = 1e-7
#     y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
#     logit_y_pred = K.log(y_pred / (1. - y_pred))
#     loss = weight * (logit_y_pred * (1. - y_true) + 
#                      K.log(1. + K.exp(-K.abs(logit_y_pred))) + K.maximum(-logit_y_pred, 0.))
#     return K.sum(loss) / K.sum(weight)

# def weighted_dice_loss(y_true, y_pred, weight):
#     smooth = 1.
#     w, m1, m2 = weight, y_true, y_pred
#     intersection = (m1 * m2)
#     score = (2. * K.sum(w * intersection) + smooth) / (K.sum(w * m1) + K.sum(w * m2) + smooth)
#     loss = 1. - K.sum(score)
#     return loss

# def weighted_bce_dice_loss(y_true, y_pred):
#     y_true = K.cast(y_true, 'float32')
#     y_pred = K.cast(y_pred, 'float32')
#     # if we want to get same size of output, kernel size must be odd
#     averaged_mask = K.pool2d(
#             y_true, pool_size=(50, 50), strides=(1, 1), padding='same', pool_mode='avg')
#     weight = K.ones_like(averaged_mask)
#     w0 = K.sum(weight)
#     weight = 5. * K.exp(-5. * K.abs(averaged_mask - 0.5))
#     w1 = K.sum(weight)
#     weight *= (w0 / w1)
#     loss = weighted_bce_loss(y_true, y_pred, weight) + dice_loss(y_true, y_pred)
#     return loss
  
# def focal_loss(gamma=2., alpha=.25):
#     def focal_loss_fixed(y_true, y_pred):
#         pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
#         pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
#         return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1))-K.sum((1-alpha) * K.pow( pt_0, gamma) * K.log(1. - pt_0))
#     return focal_loss_fixed

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 256, 256, 3)  9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 262, 262, 3)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 128, 128, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 128, 128, 64) 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 128, 128, 64) 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 130, 130, 64) 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 64, 64, 64)   0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 64, 64, 64)   256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 64, 64, 64)   0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 64, 64, 64)   4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 64, 64, 64)   0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 66, 66, 64)   0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, 64, 64, 64)   36864       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn3 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu3 (Activation) (None, 64, 64, 64)   0           stage1_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv3 (Conv2D)     (None, 64, 64, 256)  16384       stage1_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 64, 64, 256)  16384       stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 256)  0           stage1_unit1_conv3[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 64, 64, 256)  1024        add_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 64, 64, 256)  0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 64, 64, 64)   16384       stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 64, 64, 64)   0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 66, 66, 64)   0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, 64, 64, 64)   36864       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn3 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu3 (Activation) (None, 64, 64, 64)   0           stage1_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv3 (Conv2D)     (None, 64, 64, 256)  16384       stage1_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 256)  0           stage1_unit2_conv3[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn1 (BatchNormaliz (None, 64, 64, 256)  1024        add_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu1 (Activation) (None, 64, 64, 256)  0           stage1_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv1 (Conv2D)     (None, 64, 64, 64)   16384       stage1_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn2 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu2 (Activation) (None, 64, 64, 64)   0           stage1_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 66, 66, 64)   0           stage1_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv2 (Conv2D)     (None, 64, 64, 64)   36864       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn3 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu3 (Activation) (None, 64, 64, 64)   0           stage1_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv3 (Conv2D)     (None, 64, 64, 256)  16384       stage1_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 256)  0           stage1_unit3_conv3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, 64, 64, 256)  1024        add_3[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, 64, 64, 256)  0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, 64, 64, 128)  32768       stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, 64, 64, 128)  512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, 64, 64, 128)  0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 66, 66, 128)  0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn3 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu3 (Activation) (None, 32, 32, 128)  0           stage2_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv3 (Conv2D)     (None, 32, 32, 512)  65536       stage2_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, 32, 32, 512)  131072      stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 512)  0           stage2_unit1_conv3[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, 32, 32, 512)  2048        add_4[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, 32, 32, 512)  0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, 32, 32, 128)  65536       stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, 32, 32, 128)  0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 34, 34, 128)  0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn3 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu3 (Activation) (None, 32, 32, 128)  0           stage2_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv3 (Conv2D)     (None, 32, 32, 512)  65536       stage2_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 512)  0           stage2_unit2_conv3[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn1 (BatchNormaliz (None, 32, 32, 512)  2048        add_5[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu1 (Activation) (None, 32, 32, 512)  0           stage2_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv1 (Conv2D)     (None, 32, 32, 128)  65536       stage2_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn2 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu2 (Activation) (None, 32, 32, 128)  0           stage2_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 34, 34, 128)  0           stage2_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv2 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn3 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu3 (Activation) (None, 32, 32, 128)  0           stage2_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv3 (Conv2D)     (None, 32, 32, 512)  65536       stage2_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 512)  0           stage2_unit3_conv3[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn1 (BatchNormaliz (None, 32, 32, 512)  2048        add_6[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu1 (Activation) (None, 32, 32, 512)  0           stage2_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv1 (Conv2D)     (None, 32, 32, 128)  65536       stage2_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn2 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu2 (Activation) (None, 32, 32, 128)  0           stage2_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 34, 34, 128)  0           stage2_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv2 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn3 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit4_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu3 (Activation) (None, 32, 32, 128)  0           stage2_unit4_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv3 (Conv2D)     (None, 32, 32, 512)  65536       stage2_unit4_relu3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 512)  0           stage2_unit4_conv3[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, 32, 32, 512)  2048        add_7[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, 32, 32, 512)  0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, 32, 32, 256)  131072      stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, 32, 32, 256)  1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, 32, 32, 256)  0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 34, 34, 256)  0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn3 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu3 (Activation) (None, 16, 16, 256)  0           stage3_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv3 (Conv2D)     (None, 16, 16, 1024) 262144      stage3_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, 16, 16, 1024) 524288      stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 1024) 0           stage3_unit1_conv3[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, 16, 16, 1024) 4096        add_8[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, 16, 16, 1024) 0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, 16, 16, 256)  262144      stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn3 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu3 (Activation) (None, 16, 16, 256)  0           stage3_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv3 (Conv2D)     (None, 16, 16, 1024) 262144      stage3_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 1024) 0           stage3_unit2_conv3[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn1 (BatchNormaliz (None, 16, 16, 1024) 4096        add_9[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu1 (Activation) (None, 16, 16, 1024) 0           stage3_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv1 (Conv2D)     (None, 16, 16, 256)  262144      stage3_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn3 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu3 (Activation) (None, 16, 16, 256)  0           stage3_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv3 (Conv2D)     (None, 16, 16, 1024) 262144      stage3_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 1024) 0           stage3_unit3_conv3[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn1 (BatchNormaliz (None, 16, 16, 1024) 4096        add_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu1 (Activation) (None, 16, 16, 1024) 0           stage3_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv1 (Conv2D)     (None, 16, 16, 256)  262144      stage3_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn3 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit4_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu3 (Activation) (None, 16, 16, 256)  0           stage3_unit4_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv3 (Conv2D)     (None, 16, 16, 1024) 262144      stage3_unit4_relu3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 1024) 0           stage3_unit4_conv3[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn1 (BatchNormaliz (None, 16, 16, 1024) 4096        add_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu1 (Activation) (None, 16, 16, 1024) 0           stage3_unit5_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv1 (Conv2D)     (None, 16, 16, 256)  262144      stage3_unit5_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit5_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit5_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn3 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit5_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu3 (Activation) (None, 16, 16, 256)  0           stage3_unit5_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv3 (Conv2D)     (None, 16, 16, 1024) 262144      stage3_unit5_relu3[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 1024) 0           stage3_unit5_conv3[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn1 (BatchNormaliz (None, 16, 16, 1024) 4096        add_12[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu1 (Activation) (None, 16, 16, 1024) 0           stage3_unit6_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv1 (Conv2D)     (None, 16, 16, 256)  262144      stage3_unit6_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit6_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit6_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit6_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn3 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit6_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu3 (Activation) (None, 16, 16, 256)  0           stage3_unit6_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv3 (Conv2D)     (None, 16, 16, 1024) 262144      stage3_unit6_relu3[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 1024) 0           stage3_unit6_conv3[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, 16, 16, 1024) 4096        add_13[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, 16, 16, 1024) 0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, 16, 16, 512)  524288      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, 16, 16, 512)  2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, 16, 16, 512)  0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 18, 18, 512)  0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, 8, 8, 512)    2359296     zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn3 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu3 (Activation) (None, 8, 8, 512)    0           stage4_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv3 (Conv2D)     (None, 8, 8, 2048)   1048576     stage4_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, 8, 8, 2048)   2097152     stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 2048)   0           stage4_unit1_conv3[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, 8, 8, 2048)   8192        add_14[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, 8, 8, 2048)   0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, 8, 8, 512)    1048576     stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, 8, 8, 512)    0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 10, 10, 512)  0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, 8, 8, 512)    2359296     zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn3 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu3 (Activation) (None, 8, 8, 512)    0           stage4_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv3 (Conv2D)     (None, 8, 8, 2048)   1048576     stage4_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 2048)   0           stage4_unit2_conv3[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn1 (BatchNormaliz (None, 8, 8, 2048)   8192        add_15[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu1 (Activation) (None, 8, 8, 2048)   0           stage4_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv1 (Conv2D)     (None, 8, 8, 512)    1048576     stage4_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn2 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu2 (Activation) (None, 8, 8, 512)    0           stage4_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 10, 10, 512)  0           stage4_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv2 (Conv2D)     (None, 8, 8, 512)    2359296     zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn3 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu3 (Activation) (None, 8, 8, 512)    0           stage4_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv3 (Conv2D)     (None, 8, 8, 2048)   1048576     stage4_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 2048)   0           stage4_unit3_conv3[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 8, 8, 2048)   8192        add_16[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 8, 8, 2048)   0           bn1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 8, 8, 256)    524544      relu1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 16, 16, 256)  262400      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 16, 16, 256)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# add_17 (Add)                    (None, 16, 16, 256)  0           conv2d_4[0][0]
#                                                                  up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 256)  131328      stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 32, 32, 256)  0           add_17[0][0]
# __________________________________________________________________________________________________
# add_18 (Add)                    (None, 32, 32, 256)  0           conv2d_7[0][0]
#                                                                  up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 64, 64, 256)  65792       stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 256)  0           add_18[0][0]
# __________________________________________________________________________________________________
# add_19 (Add)                    (None, 64, 64, 256)  0           conv2d_10[0][0]
#                                                                  up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 128)  295040      add_18[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 128)  295040      add_17[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 8, 8, 128)    295040      conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 128)  295040      add_19[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 128)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 128)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 8, 8, 128)    0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64, 64, 128)  0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  147584      activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 8, 8, 128)    147584      activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 128)  147584      activation_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 128)  0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 8, 8, 128)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 64, 64, 128)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 64, 64, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 128)  0           activation_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 64, 64, 128)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           activation_8[0][0]
#                                                                  up_sampling2d_4[0][0]
#                                                                  up_sampling2d_5[0][0]
#                                                                  up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 512)  2359808     concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 64, 64, 512)  0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 1)    4609        activation_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 64, 64, 1)    0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 1)  0           activation_10[0][0]
# ==================================================================================================
# Total params: 28,665,034
# Trainable params: 28,619,460
# Non-trainable params: 45,574
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = Adam(lr=1e-4) , loss = 'binary_crossentropy' , metrics = [mean_iou , 'acc'])

# %%
lr_reducer = ReduceLROnPlateau(monitor = 'val_mean_iou' , factor = 0.5 , 
                               mode = 'max' , patience = 5 , verbose = 2 , min_delta = 0.01)
checkpointer = ModelCheckpoint('resnet50_fpn_97.h5', monitor='val_mean_iou', 
                               verbose=2, save_best_only=True , save_weights_only = False , mode = 'max')
early_stopper = EarlyStopping(monitor = 'val_mean_iou' , mode = 'max' , patience = 10)

# %%
results = model.fit_generator(train_gen , steps_per_epoch = 1125 , epochs = 100 ,
                              validation_data = val_gen , validation_steps = 25 ,
                              callbacks=[checkpointer , lr_reducer, early_stopper] , verbose = 1)
# Out:
# Epoch 1/100
# 1125/1125 [==============================] - 496s 441ms/step - loss: 0.1901 - mean_iou: 0.6814 - acc: 0.9249 - val_loss: 0.1532 - val_mean_iou: 0.7448 - val_acc: 0.9403
#
# Epoch 00001: val_mean_iou improved from -inf to 0.74476, saving model to resnet50_fpn_97.h5
# Epoch 2/100
# 1125/1125 [==============================] - 480s 427ms/step - loss: 0.1413 - mean_iou: 0.7636 - acc: 0.9449 - val_loss: 0.1434 - val_mean_iou: 0.7782 - val_acc: 0.9445
#
# Epoch 00002: val_mean_iou improved from 0.74476 to 0.77819, saving model to resnet50_fpn_97.h5
# Epoch 3/100
# 1125/1125 [==============================] - 480s 426ms/step - loss: 0.1230 - mean_iou: 0.7882 - acc: 0.9509 - val_loss: 0.1203 - val_mean_iou: 0.7965 - val_acc: 0.9576
#
# Epoch 00003: val_mean_iou improved from 0.77819 to 0.79653, saving model to resnet50_fpn_97.h5
# Epoch 4/100
# 1125/1125 [==============================] - 479s 426ms/step - loss: 0.1134 - mean_iou: 0.8026 - acc: 0.9535 - val_loss: 0.1684 - val_mean_iou: 0.8078 - val_acc: 0.9423
#
# Epoch 00004: val_mean_iou improved from 0.79653 to 0.80776, saving model to resnet50_fpn_97.h5
# Epoch 5/100
# 1125/1125 [==============================] - 476s 423ms/step - loss: 0.1085 - mean_iou: 0.8123 - acc: 0.9559 - val_loss: 0.2536 - val_mean_iou: 0.8160 - val_acc: 0.9199
#
# Epoch 00005: val_mean_iou improved from 0.80776 to 0.81600, saving model to resnet50_fpn_97.h5
# Epoch 6/100
# 1125/1125 [==============================] - 476s 423ms/step - loss: 0.1019 - mean_iou: 0.8191 - acc: 0.9578 - val_loss: 0.1235 - val_mean_iou: 0.8225 - val_acc: 0.9567
#
# Epoch 00006: val_mean_iou improved from 0.81600 to 0.82252, saving model to resnet50_fpn_97.h5
# Epoch 7/100
# 1125/1125 [==============================] - 476s 423ms/step - loss: 0.0963 - mean_iou: 0.8255 - acc: 0.9601 - val_loss: 0.1236 - val_mean_iou: 0.8281 - val_acc: 0.9563
#
# Epoch 00007: val_mean_iou improved from 0.82252 to 0.82813, saving model to resnet50_fpn_97.h5
# Epoch 8/100
# 1125/1125 [==============================] - 475s 422ms/step - loss: 0.0907 - mean_iou: 0.8307 - acc: 0.9622 - val_loss: 0.1408 - val_mean_iou: 0.8332 - val_acc: 0.9496
#
# Epoch 00008: val_mean_iou improved from 0.82813 to 0.83317, saving model to resnet50_fpn_97.h5
# Epoch 9/100
# 1125/1125 [==============================] - 477s 424ms/step - loss: 0.0866 - mean_iou: 0.8355 - acc: 0.9644 - val_loss: 0.1098 - val_mean_iou: 0.8378 - val_acc: 0.9584
#
# Epoch 00009: val_mean_iou improved from 0.83317 to 0.83777, saving model to resnet50_fpn_97.h5
# Epoch 10/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.0805 - mean_iou: 0.8401 - acc: 0.9663 - val_loss: 0.1362 - val_mean_iou: 0.8422 - val_acc: 0.9496
#
# Epoch 00010: val_mean_iou improved from 0.83777 to 0.84223, saving model to resnet50_fpn_97.h5
# Epoch 11/100
# 1125/1125 [==============================] - 476s 423ms/step - loss: 0.0744 - mean_iou: 0.8445 - acc: 0.9688 - val_loss: 0.1513 - val_mean_iou: 0.8466 - val_acc: 0.9438
#
# Epoch 00011: val_mean_iou improved from 0.84223 to 0.84657, saving model to resnet50_fpn_97.h5
# Epoch 12/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0723 - mean_iou: 0.8485 - acc: 0.9698 - val_loss: 0.1083 - val_mean_iou: 0.8505 - val_acc: 0.9574
#
# Epoch 00012: val_mean_iou improved from 0.84657 to 0.85048, saving model to resnet50_fpn_97.h5
# Epoch 13/100
# 1125/1125 [==============================] - 472s 420ms/step - loss: 0.0683 - mean_iou: 0.8524 - acc: 0.9710 - val_loss: 0.1062 - val_mean_iou: 0.8541 - val_acc: 0.9586
#
# Epoch 00013: val_mean_iou improved from 0.85048 to 0.85415, saving model to resnet50_fpn_97.h5
# Epoch 14/100
# 1125/1125 [==============================] - 472s 420ms/step - loss: 0.0670 - mean_iou: 0.8558 - acc: 0.9716 - val_loss: 0.1046 - val_mean_iou: 0.8575 - val_acc: 0.9617
#
# Epoch 00014: val_mean_iou improved from 0.85415 to 0.85748, saving model to resnet50_fpn_97.h5
# Epoch 15/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0624 - mean_iou: 0.8592 - acc: 0.9739 - val_loss: 0.1080 - val_mean_iou: 0.8609 - val_acc: 0.9584
#
# Epoch 00015: val_mean_iou improved from 0.85748 to 0.86088, saving model to resnet50_fpn_97.h5
# Epoch 16/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0610 - mean_iou: 0.8624 - acc: 0.9740 - val_loss: 0.1058 - val_mean_iou: 0.8639 - val_acc: 0.9634
#
# Epoch 00016: val_mean_iou improved from 0.86088 to 0.86394, saving model to resnet50_fpn_97.h5
# Epoch 17/100
# 1125/1125 [==============================] - 472s 419ms/step - loss: 0.0575 - mean_iou: 0.8654 - acc: 0.9756 - val_loss: 0.1069 - val_mean_iou: 0.8669 - val_acc: 0.9615
#
# Epoch 00017: val_mean_iou improved from 0.86394 to 0.86690, saving model to resnet50_fpn_97.h5
# Epoch 18/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0579 - mean_iou: 0.8682 - acc: 0.9758 - val_loss: 0.1365 - val_mean_iou: 0.8695 - val_acc: 0.9525
#
# Epoch 00018: val_mean_iou improved from 0.86690 to 0.86953, saving model to resnet50_fpn_97.h5
# Epoch 19/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0562 - mean_iou: 0.8708 - acc: 0.9758 - val_loss: 0.1242 - val_mean_iou: 0.8720 - val_acc: 0.9566
#
# Epoch 00019: val_mean_iou improved from 0.86953 to 0.87198, saving model to resnet50_fpn_97.h5
# Epoch 20/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.0543 - mean_iou: 0.8732 - acc: 0.9766 - val_loss: 0.1075 - val_mean_iou: 0.8743 - val_acc: 0.9571
#
# Epoch 00020: val_mean_iou improved from 0.87198 to 0.87433, saving model to resnet50_fpn_97.h5
# Epoch 21/100
# 1125/1125 [==============================] - 472s 419ms/step - loss: 0.0534 - mean_iou: 0.8754 - acc: 0.9772 - val_loss: 0.1476 - val_mean_iou: 0.8765 - val_acc: 0.9501
#
# Epoch 00021: val_mean_iou improved from 0.87433 to 0.87653, saving model to resnet50_fpn_97.h5
# Epoch 22/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0500 - mean_iou: 0.8776 - acc: 0.9786 - val_loss: 0.0985 - val_mean_iou: 0.8787 - val_acc: 0.9678
#
# Epoch 00022: val_mean_iou improved from 0.87653 to 0.87874, saving model to resnet50_fpn_97.h5
# Epoch 23/100
# 1125/1125 [==============================] - 472s 420ms/step - loss: 0.0495 - mean_iou: 0.8797 - acc: 0.9785 - val_loss: 0.1176 - val_mean_iou: 0.8808 - val_acc: 0.9588
#
# Epoch 00023: val_mean_iou improved from 0.87874 to 0.88080, saving model to resnet50_fpn_97.h5
# Epoch 24/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0497 - mean_iou: 0.8817 - acc: 0.9786 - val_loss: 0.1093 - val_mean_iou: 0.8827 - val_acc: 0.9633
#
# Epoch 00024: val_mean_iou improved from 0.88080 to 0.88266, saving model to resnet50_fpn_97.h5
# Epoch 25/100
# 1125/1125 [==============================] - 472s 420ms/step - loss: 0.0488 - mean_iou: 0.8836 - acc: 0.9792 - val_loss: 0.1050 - val_mean_iou: 0.8845 - val_acc: 0.9714
#
# Epoch 00025: val_mean_iou improved from 0.88266 to 0.88448, saving model to resnet50_fpn_97.h5
# Epoch 26/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0474 - mean_iou: 0.8854 - acc: 0.9793 - val_loss: 0.0931 - val_mean_iou: 0.8862 - val_acc: 0.9639
#
# Epoch 00026: val_mean_iou improved from 0.88448 to 0.88618, saving model to resnet50_fpn_97.h5
# Epoch 27/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0440 - mean_iou: 0.8871 - acc: 0.9809 - val_loss: 0.1107 - val_mean_iou: 0.8880 - val_acc: 0.9556
#
# Epoch 00027: val_mean_iou improved from 0.88618 to 0.88795, saving model to resnet50_fpn_97.h5
# Epoch 28/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0458 - mean_iou: 0.8887 - acc: 0.9798 - val_loss: 0.1213 - val_mean_iou: 0.8895 - val_acc: 0.9571
#
# Epoch 00028: val_mean_iou improved from 0.88795 to 0.88946, saving model to resnet50_fpn_97.h5
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 29/100
# 1125/1125 [==============================] - 475s 423ms/step - loss: 0.0331 - mean_iou: 0.8905 - acc: 0.9846 - val_loss: 0.0960 - val_mean_iou: 0.8915 - val_acc: 0.9714
#
# Epoch 00029: val_mean_iou improved from 0.88946 to 0.89151, saving model to resnet50_fpn_97.h5
# Epoch 30/100
# 1125/1125 [==============================] - 472s 419ms/step - loss: 0.0329 - mean_iou: 0.8925 - acc: 0.9846 - val_loss: 0.1047 - val_mean_iou: 0.8934 - val_acc: 0.9666
#
# Epoch 00030: val_mean_iou improved from 0.89151 to 0.89343, saving model to resnet50_fpn_97.h5
# Epoch 31/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0294 - mean_iou: 0.8944 - acc: 0.9859 - val_loss: 0.1134 - val_mean_iou: 0.8954 - val_acc: 0.9681
#
# Epoch 00031: val_mean_iou improved from 0.89343 to 0.89537, saving model to resnet50_fpn_97.h5
# Epoch 32/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0314 - mean_iou: 0.8963 - acc: 0.9851 - val_loss: 0.0804 - val_mean_iou: 0.8971 - val_acc: 0.9707
#
# Epoch 00032: val_mean_iou improved from 0.89537 to 0.89711, saving model to resnet50_fpn_97.h5
# Epoch 33/100
# 1125/1125 [==============================] - 476s 423ms/step - loss: 0.0306 - mean_iou: 0.8979 - acc: 0.9853 - val_loss: 0.1363 - val_mean_iou: 0.8988 - val_acc: 0.9590
#
# Epoch 00033: val_mean_iou improved from 0.89711 to 0.89876, saving model to resnet50_fpn_97.h5
# Epoch 34/100
# 1125/1125 [==============================] - 472s 419ms/step - loss: 0.0270 - mean_iou: 0.8996 - acc: 0.9866 - val_loss: 0.0884 - val_mean_iou: 0.9005 - val_acc: 0.9707
#
# Epoch 00034: val_mean_iou improved from 0.89876 to 0.90045, saving model to resnet50_fpn_97.h5
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 35/100
# 1125/1125 [==============================] - 480s 426ms/step - loss: 0.0247 - mean_iou: 0.9013 - acc: 0.9875 - val_loss: 0.1397 - val_mean_iou: 0.9021 - val_acc: 0.9637
#
# Epoch 00035: val_mean_iou improved from 0.90045 to 0.90213, saving model to resnet50_fpn_97.h5
# Epoch 36/100
# 1125/1125 [==============================] - 477s 424ms/step - loss: 0.0240 - mean_iou: 0.9030 - acc: 0.9878 - val_loss: 0.1189 - val_mean_iou: 0.9038 - val_acc: 0.9665
#
# Epoch 00036: val_mean_iou improved from 0.90213 to 0.90376, saving model to resnet50_fpn_97.h5
# Epoch 37/100
# 1125/1125 [==============================] - 477s 424ms/step - loss: 0.0240 - mean_iou: 0.9045 - acc: 0.9879 - val_loss: 0.1013 - val_mean_iou: 0.9053 - val_acc: 0.9678
#
# Epoch 00037: val_mean_iou improved from 0.90376 to 0.90532, saving model to resnet50_fpn_97.h5
# Epoch 38/100
# 1125/1125 [==============================] - 479s 425ms/step - loss: 0.0235 - mean_iou: 0.9061 - acc: 0.9879 - val_loss: 0.1181 - val_mean_iou: 0.9068 - val_acc: 0.9701
#
# Epoch 00038: val_mean_iou improved from 0.90532 to 0.90680, saving model to resnet50_fpn_97.h5
# Epoch 39/100
# 1125/1125 [==============================] - 481s 427ms/step - loss: 0.0228 - mean_iou: 0.9075 - acc: 0.9882 - val_loss: 0.1855 - val_mean_iou: 0.9082 - val_acc: 0.9609
#
# Epoch 00039: val_mean_iou improved from 0.90680 to 0.90822, saving model to resnet50_fpn_97.h5
# Epoch 40/100
# 1125/1125 [==============================] - 480s 426ms/step - loss: 0.0223 - mean_iou: 0.9089 - acc: 0.9884 - val_loss: 0.1478 - val_mean_iou: 0.9096 - val_acc: 0.9653
#
# Epoch 00040: val_mean_iou improved from 0.90822 to 0.90959, saving model to resnet50_fpn_97.h5
#
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 41/100
# 1125/1125 [==============================] - 481s 427ms/step - loss: 0.0213 - mean_iou: 0.9103 - acc: 0.9888 - val_loss: 0.1518 - val_mean_iou: 0.9109 - val_acc: 0.9655
#
# Epoch 00041: val_mean_iou improved from 0.90959 to 0.91092, saving model to resnet50_fpn_97.h5
# Epoch 42/100
# 1125/1125 [==============================] - 483s 429ms/step - loss: 0.0211 - mean_iou: 0.9116 - acc: 0.9889 - val_loss: 0.1438 - val_mean_iou: 0.9122 - val_acc: 0.9672
#
# Epoch 00042: val_mean_iou improved from 0.91092 to 0.91222, saving model to resnet50_fpn_97.h5
# Epoch 43/100
# 1125/1125 [==============================] - 481s 428ms/step - loss: 0.0205 - mean_iou: 0.9128 - acc: 0.9890 - val_loss: 0.1342 - val_mean_iou: 0.9135 - val_acc: 0.9680
#
# Epoch 00043: val_mean_iou improved from 0.91222 to 0.91346, saving model to resnet50_fpn_97.h5
# Epoch 44/100
# 1125/1125 [==============================] - 477s 424ms/step - loss: 0.0207 - mean_iou: 0.9141 - acc: 0.9890 - val_loss: 0.1163 - val_mean_iou: 0.9147 - val_acc: 0.9721
#
# Epoch 00044: val_mean_iou improved from 0.91346 to 0.91465, saving model to resnet50_fpn_97.h5
# Epoch 45/100
# 1125/1125 [==============================] - 479s 426ms/step - loss: 0.0206 - mean_iou: 0.9152 - acc: 0.9891 - val_loss: 0.1510 - val_mean_iou: 0.9158 - val_acc: 0.9653
#
# Epoch 00045: val_mean_iou improved from 0.91465 to 0.91580, saving model to resnet50_fpn_97.h5
# Epoch 46/100
# 1125/1125 [==============================] - 482s 428ms/step - loss: 0.0199 - mean_iou: 0.9164 - acc: 0.9893 - val_loss: 0.1495 - val_mean_iou: 0.9169 - val_acc: 0.9649
#
# Epoch 00046: val_mean_iou improved from 0.91580 to 0.91689, saving model to resnet50_fpn_97.h5
# Epoch 47/100
# 1125/1125 [==============================] - 481s 428ms/step - loss: 0.0199 - mean_iou: 0.9174 - acc: 0.9893 - val_loss: 0.1533 - val_mean_iou: 0.9180 - val_acc: 0.9629
#
# Epoch 00047: val_mean_iou improved from 0.91689 to 0.91795, saving model to resnet50_fpn_97.h5
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 48/100
# 1125/1125 [==============================] - 479s 426ms/step - loss: 0.0195 - mean_iou: 0.9185 - acc: 0.9895 - val_loss: 0.0907 - val_mean_iou: 0.9190 - val_acc: 0.9744
#
# Epoch 00048: val_mean_iou improved from 0.91795 to 0.91898, saving model to resnet50_fpn_97.h5
# Epoch 49/100
# 1125/1125 [==============================] - 479s 426ms/step - loss: 0.0192 - mean_iou: 0.9195 - acc: 0.9895 - val_loss: 0.1475 - val_mean_iou: 0.9200 - val_acc: 0.9683
#
# Epoch 00049: val_mean_iou improved from 0.91898 to 0.91997, saving model to resnet50_fpn_97.h5
# Epoch 50/100
# 1125/1125 [==============================] - 483s 430ms/step - loss: 0.0191 - mean_iou: 0.9205 - acc: 0.9896 - val_loss: 0.1955 - val_mean_iou: 0.9209 - val_acc: 0.9626
#
# Epoch 00050: val_mean_iou improved from 0.91997 to 0.92093, saving model to resnet50_fpn_97.h5
# Epoch 51/100
# 1125/1125 [==============================] - 480s 427ms/step - loss: 0.0189 - mean_iou: 0.9214 - acc: 0.9897 - val_loss: 0.1639 - val_mean_iou: 0.9219 - val_acc: 0.9661
#
# Epoch 00051: val_mean_iou improved from 0.92093 to 0.92185, saving model to resnet50_fpn_97.h5
# Epoch 52/100
# 1125/1125 [==============================] - 481s 428ms/step - loss: 0.0189 - mean_iou: 0.9223 - acc: 0.9897 - val_loss: 0.1298 - val_mean_iou: 0.9227 - val_acc: 0.9696
#
# Epoch 00052: val_mean_iou improved from 0.92185 to 0.92274, saving model to resnet50_fpn_97.h5
# Epoch 53/100
# 1125/1125 [==============================] - 478s 425ms/step - loss: 0.0188 - mean_iou: 0.9232 - acc: 0.9897 - val_loss: 0.1615 - val_mean_iou: 0.9236 - val_acc: 0.9656
#
# Epoch 00053: val_mean_iou improved from 0.92274 to 0.92360, saving model to resnet50_fpn_97.h5
# Epoch 54/100
# 1125/1125 [==============================] - 480s 427ms/step - loss: 0.0185 - mean_iou: 0.9240 - acc: 0.9898 - val_loss: 0.1807 - val_mean_iou: 0.9244 - val_acc: 0.9629
#
# Epoch 00054: val_mean_iou improved from 0.92360 to 0.92443, saving model to resnet50_fpn_97.h5
# Epoch 55/100
# 1125/1125 [==============================] - 477s 424ms/step - loss: 0.0185 - mean_iou: 0.9248 - acc: 0.9899 - val_loss: 0.2199 - val_mean_iou: 0.9252 - val_acc: 0.9594
#
# Epoch 00055: val_mean_iou improved from 0.92443 to 0.92523, saving model to resnet50_fpn_97.h5
# Epoch 56/100
# 1125/1125 [==============================] - 476s 423ms/step - loss: 0.0185 - mean_iou: 0.9256 - acc: 0.9898 - val_loss: 0.1590 - val_mean_iou: 0.9260 - val_acc: 0.9680
#
# Epoch 00056: val_mean_iou improved from 0.92523 to 0.92600, saving model to resnet50_fpn_97.h5
# Epoch 57/100
# 1125/1125 [==============================] - 478s 425ms/step - loss: 0.0184 - mean_iou: 0.9264 - acc: 0.9898 - val_loss: 0.1464 - val_mean_iou: 0.9268 - val_acc: 0.9685
#
# Epoch 00057: val_mean_iou improved from 0.92600 to 0.92676, saving model to resnet50_fpn_97.h5
#
# Epoch 00057: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-06.
# Epoch 58/100
# 1125/1125 [==============================] - 477s 424ms/step - loss: 0.0182 - mean_iou: 0.9271 - acc: 0.9899 - val_loss: 0.1597 - val_mean_iou: 0.9275 - val_acc: 0.9692
#
# Epoch 00058: val_mean_iou improved from 0.92676 to 0.92749, saving model to resnet50_fpn_97.h5
# Epoch 59/100
# 1125/1125 [==============================] - 480s 427ms/step - loss: 0.0182 - mean_iou: 0.9278 - acc: 0.9899 - val_loss: 0.1025 - val_mean_iou: 0.9282 - val_acc: 0.9736
#
# Epoch 00059: val_mean_iou improved from 0.92749 to 0.92820, saving model to resnet50_fpn_97.h5
# Epoch 60/100
# 1125/1125 [==============================] - 480s 427ms/step - loss: 0.0181 - mean_iou: 0.9285 - acc: 0.9900 - val_loss: 0.1501 - val_mean_iou: 0.9289 - val_acc: 0.9686
#
# Epoch 00060: val_mean_iou improved from 0.92820 to 0.92889, saving model to resnet50_fpn_97.h5
# Epoch 61/100
# 1125/1125 [==============================] - 479s 426ms/step - loss: 0.0179 - mean_iou: 0.9292 - acc: 0.9900 - val_loss: 0.1734 - val_mean_iou: 0.9296 - val_acc: 0.9661
#
# Epoch 00061: val_mean_iou improved from 0.92889 to 0.92956, saving model to resnet50_fpn_97.h5
# Epoch 62/100
# 1125/1125 [==============================] - 475s 423ms/step - loss: 0.0181 - mean_iou: 0.9299 - acc: 0.9900 - val_loss: 0.1167 - val_mean_iou: 0.9302 - val_acc: 0.9724
#
# Epoch 00062: val_mean_iou improved from 0.92956 to 0.93020, saving model to resnet50_fpn_97.h5
#
# Epoch 00062: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-06.
# Epoch 63/100
# 1125/1125 [==============================] - 479s 426ms/step - loss: 0.0179 - mean_iou: 0.9305 - acc: 0.9900 - val_loss: 0.1824 - val_mean_iou: 0.9308 - val_acc: 0.9619
#
# Epoch 00063: val_mean_iou improved from 0.93020 to 0.93083, saving model to resnet50_fpn_97.h5
# Epoch 64/100
# 1125/1125 [==============================] - 472s 420ms/step - loss: 0.0181 - mean_iou: 0.9311 - acc: 0.9900 - val_loss: 0.1609 - val_mean_iou: 0.9314 - val_acc: 0.9691
#
# Epoch 00064: val_mean_iou improved from 0.93083 to 0.93143, saving model to resnet50_fpn_97.h5
# Epoch 65/100
# 1125/1125 [==============================] - 472s 420ms/step - loss: 0.0179 - mean_iou: 0.9317 - acc: 0.9901 - val_loss: 0.1677 - val_mean_iou: 0.9320 - val_acc: 0.9689
#
# Epoch 00065: val_mean_iou improved from 0.93143 to 0.93202, saving model to resnet50_fpn_97.h5
# Epoch 66/100
# 1125/1125 [==============================] - 478s 425ms/step - loss: 0.0177 - mean_iou: 0.9323 - acc: 0.9901 - val_loss: 0.1745 - val_mean_iou: 0.9326 - val_acc: 0.9657
#
# Epoch 00066: val_mean_iou improved from 0.93202 to 0.93259, saving model to resnet50_fpn_97.h5
# Epoch 67/100
# 1125/1125 [==============================] - 478s 425ms/step - loss: 0.0178 - mean_iou: 0.9329 - acc: 0.9900 - val_loss: 0.2116 - val_mean_iou: 0.9332 - val_acc: 0.9628
#
# Epoch 00067: val_mean_iou improved from 0.93259 to 0.93315, saving model to resnet50_fpn_97.h5
# Epoch 68/100
# 1125/1125 [==============================] - 477s 424ms/step - loss: 0.0177 - mean_iou: 0.9334 - acc: 0.9901 - val_loss: 0.1421 - val_mean_iou: 0.9337 - val_acc: 0.9682
#
# Epoch 00068: val_mean_iou improved from 0.93315 to 0.93369, saving model to resnet50_fpn_97.h5
# Epoch 69/100
# 1125/1125 [==============================] - 479s 426ms/step - loss: 0.0177 - mean_iou: 0.9340 - acc: 0.9901 - val_loss: 0.1423 - val_mean_iou: 0.9342 - val_acc: 0.9694
#
# Epoch 00069: val_mean_iou improved from 0.93369 to 0.93422, saving model to resnet50_fpn_97.h5
# Epoch 70/100
# 1125/1125 [==============================] - 477s 424ms/step - loss: 0.0177 - mean_iou: 0.9345 - acc: 0.9901 - val_loss: 0.1964 - val_mean_iou: 0.9347 - val_acc: 0.9629
#
# Epoch 00070: val_mean_iou improved from 0.93422 to 0.93473, saving model to resnet50_fpn_97.h5
# Epoch 71/100
# 1125/1125 [==============================] - 476s 423ms/step - loss: 0.0177 - mean_iou: 0.9350 - acc: 0.9901 - val_loss: 0.1747 - val_mean_iou: 0.9352 - val_acc: 0.9657
#
# Epoch 00071: val_mean_iou improved from 0.93473 to 0.93522, saving model to resnet50_fpn_97.h5
# Epoch 72/100
# 1125/1125 [==============================] - 478s 425ms/step - loss: 0.0175 - mean_iou: 0.9355 - acc: 0.9902 - val_loss: 0.2243 - val_mean_iou: 0.9357 - val_acc: 0.9594
#
# Epoch 00072: val_mean_iou improved from 0.93522 to 0.93571, saving model to resnet50_fpn_97.h5
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-07.
# Epoch 73/100
# 1125/1125 [==============================] - 479s 426ms/step - loss: 0.0177 - mean_iou: 0.9359 - acc: 0.9901 - val_loss: 0.1537 - val_mean_iou: 0.9362 - val_acc: 0.9654
#
# Epoch 00073: val_mean_iou improved from 0.93571 to 0.93617, saving model to resnet50_fpn_97.h5
# Epoch 74/100
# 1125/1125 [==============================] - 481s 427ms/step - loss: 0.0175 - mean_iou: 0.9364 - acc: 0.9902 - val_loss: 0.1866 - val_mean_iou: 0.9366 - val_acc: 0.9625
#
# Epoch 00074: val_mean_iou improved from 0.93617 to 0.93664, saving model to resnet50_fpn_97.h5
# Epoch 75/100
# 1125/1125 [==============================] - 476s 423ms/step - loss: 0.0175 - mean_iou: 0.9369 - acc: 0.9902 - val_loss: 0.2038 - val_mean_iou: 0.9371 - val_acc: 0.9670
#
# Epoch 00075: val_mean_iou improved from 0.93664 to 0.93708, saving model to resnet50_fpn_97.h5
# Epoch 76/100
# 1125/1125 [==============================] - 479s 426ms/step - loss: 0.0177 - mean_iou: 0.9373 - acc: 0.9901 - val_loss: 0.1732 - val_mean_iou: 0.9375 - val_acc: 0.9656
#
# Epoch 00076: val_mean_iou improved from 0.93708 to 0.93752, saving model to resnet50_fpn_97.h5
# Epoch 77/100
# 1125/1125 [==============================] - 480s 427ms/step - loss: 0.0175 - mean_iou: 0.9377 - acc: 0.9902 - val_loss: 0.1557 - val_mean_iou: 0.9379 - val_acc: 0.9665
#
# Epoch 00077: val_mean_iou improved from 0.93752 to 0.93795, saving model to resnet50_fpn_97.h5
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 3.906249901319825e-07.
# Epoch 78/100
# 1125/1125 [==============================] - 477s 424ms/step - loss: 0.0175 - mean_iou: 0.9382 - acc: 0.9902 - val_loss: 0.1279 - val_mean_iou: 0.9384 - val_acc: 0.9702
#
# Epoch 00078: val_mean_iou improved from 0.93795 to 0.93836, saving model to resnet50_fpn_97.h5
# Epoch 79/100
# 1125/1125 [==============================] - 477s 424ms/step - loss: 0.0174 - mean_iou: 0.9386 - acc: 0.9902 - val_loss: 0.1781 - val_mean_iou: 0.9388 - val_acc: 0.9670
#
# Epoch 00079: val_mean_iou improved from 0.93836 to 0.93877, saving model to resnet50_fpn_97.h5
# Epoch 80/100
# 1125/1125 [==============================] - 481s 428ms/step - loss: 0.0174 - mean_iou: 0.9390 - acc: 0.9902 - val_loss: 0.1404 - val_mean_iou: 0.9392 - val_acc: 0.9707
#
# Epoch 00080: val_mean_iou improved from 0.93877 to 0.93917, saving model to resnet50_fpn_97.h5
# Epoch 81/100
# 1125/1125 [==============================] - 481s 427ms/step - loss: 0.0175 - mean_iou: 0.9394 - acc: 0.9902 - val_loss: 0.1769 - val_mean_iou: 0.9396 - val_acc: 0.9657
#
# Epoch 00081: val_mean_iou improved from 0.93917 to 0.93955, saving model to resnet50_fpn_97.h5
# Epoch 82/100
# 1125/1125 [==============================] - 476s 423ms/step - loss: 0.0176 - mean_iou: 0.9397 - acc: 0.9902 - val_loss: 0.1679 - val_mean_iou: 0.9399 - val_acc: 0.9684
#
# Epoch 00082: val_mean_iou improved from 0.93955 to 0.93993, saving model to resnet50_fpn_97.h5
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 1.9531249506599124e-07.
# Epoch 83/100
# 1125/1125 [==============================] - 475s 422ms/step - loss: 0.0176 - mean_iou: 0.9401 - acc: 0.9901 - val_loss: 0.1765 - val_mean_iou: 0.9403 - val_acc: 0.9663
#
# Epoch 00083: val_mean_iou improved from 0.93993 to 0.94029, saving model to resnet50_fpn_97.h5
# Epoch 84/100
# 1125/1125 [==============================] - 478s 425ms/step - loss: 0.0174 - mean_iou: 0.9405 - acc: 0.9902 - val_loss: 0.1676 - val_mean_iou: 0.9407 - val_acc: 0.9643
#
# Epoch 00084: val_mean_iou improved from 0.94029 to 0.94065, saving model to resnet50_fpn_97.h5
# Epoch 85/100
# 1125/1125 [==============================] - 476s 423ms/step - loss: 0.0174 - mean_iou: 0.9408 - acc: 0.9902 - val_loss: 0.2312 - val_mean_iou: 0.9410 - val_acc: 0.9625
#
# Epoch 00085: val_mean_iou improved from 0.94065 to 0.94100, saving model to resnet50_fpn_97.h5
# Epoch 86/100
# 1125/1125 [==============================] - 479s 426ms/step - loss: 0.0174 - mean_iou: 0.9412 - acc: 0.9903 - val_loss: 0.1746 - val_mean_iou: 0.9413 - val_acc: 0.9661
#
# Epoch 00086: val_mean_iou improved from 0.94100 to 0.94134, saving model to resnet50_fpn_97.h5
# Epoch 87/100
# 1125/1125 [==============================] - 480s 426ms/step - loss: 0.0174 - mean_iou: 0.9415 - acc: 0.9902 - val_loss: 0.1466 - val_mean_iou: 0.9417 - val_acc: 0.9706
#
# Epoch 00087: val_mean_iou improved from 0.94134 to 0.94168, saving model to resnet50_fpn_97.h5
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 9.765624753299562e-08.
# Epoch 88/100
# 1125/1125 [==============================] - 482s 428ms/step - loss: 0.0173 - mean_iou: 0.9418 - acc: 0.9902 - val_loss: 0.1703 - val_mean_iou: 0.9420 - val_acc: 0.9645
#
# Epoch 00088: val_mean_iou improved from 0.94168 to 0.94201, saving model to resnet50_fpn_97.h5
# Epoch 89/100
# 1125/1125 [==============================] - 483s 429ms/step - loss: 0.0172 - mean_iou: 0.9422 - acc: 0.9903 - val_loss: 0.2094 - val_mean_iou: 0.9423 - val_acc: 0.9629
#
# Epoch 00089: val_mean_iou improved from 0.94201 to 0.94233, saving model to resnet50_fpn_97.h5
# Epoch 90/100
# 1125/1125 [==============================] - 480s 426ms/step - loss: 0.0174 - mean_iou: 0.9425 - acc: 0.9902 - val_loss: 0.1488 - val_mean_iou: 0.9426 - val_acc: 0.9657
#
# Epoch 00090: val_mean_iou improved from 0.94233 to 0.94264, saving model to resnet50_fpn_97.h5
# Epoch 91/100
# 1125/1125 [==============================] - 480s 426ms/step - loss: 0.0175 - mean_iou: 0.9428 - acc: 0.9902 - val_loss: 0.1751 - val_mean_iou: 0.9430 - val_acc: 0.9658
#
# Epoch 00091: val_mean_iou improved from 0.94264 to 0.94295, saving model to resnet50_fpn_97.h5
# Epoch 92/100
# 1125/1125 [==============================] - 480s 427ms/step - loss: 0.0175 - mean_iou: 0.9431 - acc: 0.9902 - val_loss: 0.1736 - val_mean_iou: 0.9432 - val_acc: 0.9632
#
# Epoch 00092: val_mean_iou improved from 0.94295 to 0.94325, saving model to resnet50_fpn_97.h5
# Epoch 93/100
# 1125/1125 [==============================] - 479s 426ms/step - loss: 0.0175 - mean_iou: 0.9434 - acc: 0.9902 - val_loss: 0.1900 - val_mean_iou: 0.9435 - val_acc: 0.9672
#
# Epoch 00093: val_mean_iou improved from 0.94325 to 0.94354, saving model to resnet50_fpn_97.h5
# Epoch 94/100
# 1125/1125 [==============================] - 482s 429ms/step - loss: 0.0173 - mean_iou: 0.9437 - acc: 0.9902 - val_loss: 0.1943 - val_mean_iou: 0.9438 - val_acc: 0.9659
#
# Epoch 00094: val_mean_iou improved from 0.94354 to 0.94382, saving model to resnet50_fpn_97.h5
# Epoch 95/100
# 1125/1125 [==============================] - 480s 426ms/step - loss: 0.0174 - mean_iou: 0.9440 - acc: 0.9903 - val_loss: 0.1360 - val_mean_iou: 0.9441 - val_acc: 0.9698
#
# Epoch 00095: val_mean_iou improved from 0.94382 to 0.94411, saving model to resnet50_fpn_97.h5
# Epoch 96/100
# 1125/1125 [==============================] - 480s 427ms/step - loss: 0.0175 - mean_iou: 0.9442 - acc: 0.9902 - val_loss: 0.1747 - val_mean_iou: 0.9444 - val_acc: 0.9660
#
# Epoch 00096: val_mean_iou improved from 0.94411 to 0.94438, saving model to resnet50_fpn_97.h5
# Epoch 97/100
# 1125/1125 [==============================] - 481s 428ms/step - loss: 0.0174 - mean_iou: 0.9445 - acc: 0.9902 - val_loss: 0.1743 - val_mean_iou: 0.9447 - val_acc: 0.9649
#
# Epoch 00097: val_mean_iou improved from 0.94438 to 0.94465, saving model to resnet50_fpn_97.h5
#
# Epoch 00097: ReduceLROnPlateau reducing learning rate to 4.882812376649781e-08.
# Epoch 98/100
# 1125/1125 [==============================] - 481s 427ms/step - loss: 0.0173 - mean_iou: 0.9448 - acc: 0.9903 - val_loss: 0.1871 - val_mean_iou: 0.9449 - val_acc: 0.9665
#
# Epoch 00098: val_mean_iou improved from 0.94465 to 0.94492, saving model to resnet50_fpn_97.h5
# Epoch 99/100
# 1125/1125 [==============================] - 478s 425ms/step - loss: 0.0174 - mean_iou: 0.9450 - acc: 0.9902 - val_loss: 0.1741 - val_mean_iou: 0.9452 - val_acc: 0.9635
#
# Epoch 00099: val_mean_iou improved from 0.94492 to 0.94517, saving model to resnet50_fpn_97.h5
# Epoch 100/100
# 1125/1125 [==============================] - 478s 425ms/step - loss: 0.0175 - mean_iou: 0.9453 - acc: 0.9902 - val_loss: 0.1718 - val_mean_iou: 0.9454 - val_acc: 0.9685
#
# Epoch 00100: val_mean_iou improved from 0.94517 to 0.94543, saving model to resnet50_fpn_97.h5

# %%
X_test = np.zeros((len(test_ids), im_height, im_width, im_chan), dtype=np.uint8)
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in enumerate(test_ids):
    path = path_test
    img = load_img(path + '/images/' + id_)
    x = img_to_array(img)[:,:,1]
    x = resize(x, (256, 256, 3) , preserve_range=True)
    X_test[n] = x

print('Done!')
# Out:
# Getting and resizing test images ...
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Done!

# %%
model = load_model("resnet50_fpn_97.h5" , custom_objects = {'mean_iou' : mean_iou})

# %%
preds_val = model.predict(X_val, verbose=1 , batch_size = 2)
preds_test = model.predict(X_test , verbose = 1 , batch_size = 2)

preds_val_t = (preds_val > 0.5).astype(np.uint8)
# Out:
# 400/400 [==============================] - 9s 22ms/step
# 18000/18000 [==============================] - 255s 14ms/step

# %%
model.evaluate(X_val , Y_val , verbose = 1)
# Out:
# 400/400 [==============================] - 13s 33ms/step
# [0.17605403691530228, 0.8267267084121704, 0.9658163833618164]

# %%
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (101, 101), 
                                       mode='constant', preserve_range=True))

# %%
def iou_metric(y_true_in, y_pred_in, print_table=False):
    
    labels = y_true_in
    y_pred = y_pred_in
    
    true_objects = 2
    pred_objects = 2

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)
    
    union = area_true + area_pred - intersection

    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    iou = intersection / union

    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
thres = np.linspace(0.25, 0.75, 20)
thres_ioc = [iou_metric_batch(Y_val, np.int32(preds_val > t)) for t in thres]

# %%
plt.plot(thres, thres_ioc)

# %%
best_thres = thres[np.argmax(thres_ioc)]
best_thres, max(thres_ioc)
# Out:
# (0.513157894736842, 0.8245)

# %%
def RLenc(img, order='F', format=True):
    """
    img is binary mask image, shape (r,c)
    order is down-then-right, i.e. Fortran
    format determines if the order needs to be preformatted (according to submission rules) or not

    returns run length as an array or string (if format is True)
    """
    bytes = img.reshape(img.shape[0] * img.shape[1], order=order)
    runs = []  ## list of run lengths
    r = 0  ## the current run length
    pos = 1  ## count starts from 1 per WK
    for c in bytes:
        if (c == 0):
            if r != 0:
                runs.append((pos, r))
                pos += r
                r = 0
            pos += 1
        else:
            r += 1

    # if last run is unsaved (i.e. data ends with 1)
    if r != 0:
        runs.append((pos, r))
        pos += r
        r = 0

    if format:
        z = ''

        for rr in runs:
            z += '{} {} '.format(rr[0], rr[1])
        return z[:-1]
    else:
        return runs

pred_dict = {fn[:-4]:RLenc(np.round(preds_test_upsampled[i] > best_thres)) for i,fn in enumerate(test_ids)}

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv('submission.csv')

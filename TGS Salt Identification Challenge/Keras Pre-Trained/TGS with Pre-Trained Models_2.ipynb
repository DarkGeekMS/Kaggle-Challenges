# %%
import os
import sys
import random
import warnings

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from segmentation_models import Unet
from segmentation_models.utils import set_trainable

from itertools import chain
from skimage.io import imread, imshow, concatenate_images
from skimage.transform import resize
from skimage.morphology import label
from sklearn.model_selection import train_test_split

from keras.applications.resnet50 import ResNet50
from keras.models import Model, load_model
from keras.layers import Input , Concatenate
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.convolutional import Conv2D, Conv2DTranspose
from keras.layers.pooling import MaxPooling2D
from keras.layers.merge import concatenate
from keras.layers import *
from keras.initializers import he_normal
from keras.regularizers import l2
from keras.layers import Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras import backend as K
from keras.optimizers import *
from keras.utils import to_categorical
from keras.losses import binary_crossentropy
import tensorflow as tf

from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
im_width = 256
im_height = 256
border = 5
im_chan = 3
n_features = 1 
path_train = 'data/train/'
path_test = 'data/test/'

# %%
ids= ['1f1cc6b3a4','5b7c160d0d','6c40978ddf','7dfdf6eeb8','7e5a6e5013']
plt.figure(figsize=(20,10))
for j, img_name in enumerate(ids):
    q = j+1
    img = load_img('data/train/images/' + img_name + '.png')
    img_mask = load_img('data/train/masks/' + img_name + '.png')
    
    plt.subplot(1,2*(1+len(ids)),q*2-1)
    plt.imshow(img)
    plt.subplot(1,2*(1+len(ids)),q*2)
    plt.imshow(img_mask)
plt.show()

# %%
train_ids = next(os.walk(path_train+"images"))[2]
test_ids = next(os.walk(path_test+"images"))[2]

# %%
X_train = np.zeros((len(train_ids), im_height, im_width, im_chan), dtype=np.uint8)
Y_train = np.zeros((len(train_ids), 256, 256 , 1), dtype=np.bool)
print('Getting and resizing train images and masks ... ')
sys.stdout.flush()
sum_whites = 0
for n, id_ in enumerate(train_ids):
    path = path_train
    img = load_img(path + '/images/' + id_)
    x = img_to_array(img)[:,:,1]
    x = resize(x, (256, 256 , 3), preserve_range=True)
    X_train[n] = x
    mask = img_to_array(load_img(path + '/masks/' + id_))[:,:,1]
    Y_train[n] = resize(mask, (256, 256, 1), preserve_range=True)
    sum_whites += np.sum(Y_train[n])

print('Done!')

print("Salt in the dataset is {}".format(sum_whites*1.0 / (X_train.shape[0] * 256*256)))
# Out:
# Getting and resizing train images and masks ...
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Done!
# Salt in the dataset is 0.24794946670532225

# %%
Y_train[0].shape
# Out:
# (256, 256, 1)

# %%
ix = random.randint(0, len(train_ids))
plt.imshow(X_train[ix])
plt.show()
tmp = np.squeeze(Y_train[ix]).astype(np.float32)
plt.imshow(np.dstack((tmp,tmp,tmp)))
plt.show()

# %%
X_train , X_val , Y_train , Y_val = train_test_split(X_train , Y_train , train_size = 0.9 , random_state = 1998)
# Out:
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\sklearn\model_selection\_split.py:2026: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
image_generator = ImageDataGenerator(
    horizontal_flip=True,
    vertical_flip = True,
    zoom_range = 0.2,
    width_shift_range = 0.2,
    height_shift_range = 0.2
)

mask_generator = ImageDataGenerator(
    horizontal_flip=True,
    vertical_flip = True,
    zoom_range = 0.2,
    width_shift_range = 0.2,
    height_shift_range = 0.2
)

val_image_generator = ImageDataGenerator(
)
val_mask_generator = ImageDataGenerator(
)

train_img_gen = image_generator.flow(X_train , seed = 1998 , batch_size = 16)
train_mask_gen = mask_generator.flow(Y_train , seed = 1998 , batch_size = 16)

val_img_gen = val_image_generator.flow(X_val , seed = 1998 , batch_size = 16)
val_mask_gen = val_mask_generator.flow(Y_val , seed = 1998 , batch_size = 16)

# %%
train_gen = zip(train_img_gen , train_mask_gen)
val_gen = zip(val_img_gen , val_mask_gen)

# %%
def mean_iou(y_true, y_pred):
    prec = []
    for t in np.arange(0.5, 1.0, 0.05):
        y_pred_ = tf.to_int32(y_pred > t)
        score, up_opt = tf.metrics.mean_iou(y_true, y_pred_, 2)
        K.get_session().run(tf.local_variables_initializer())
        with tf.control_dependencies([up_opt]):
            score = tf.identity(score)
        prec.append(score)
    return K.mean(K.stack(prec), axis=0)

# %%
model = Unet(backbone_name='resnet50', input_shape = (256,256,3))
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet50_imagenet_1000_no_top.h5
# 94593024/94592056 [==============================] - 470s 5us/step

# %%
# def dice_coef(y_true, y_pred):
#     y_true_f = K.flatten(y_true)
#     y_pred = K.cast(y_pred, 'float32')
#     y_pred_f = K.cast(K.greater(K.flatten(y_pred), 0.5), 'float32')
#     intersection = y_true_f * y_pred_f
#     score = 2. * K.sum(intersection) / (K.sum(y_true_f) + K.sum(y_pred_f))
#     return score

# def dice_loss(y_true, y_pred):
#     smooth = 1.
#     y_true_f = K.flatten(y_true)
#     y_pred_f = K.flatten(y_pred)
#     intersection = y_true_f * y_pred_f
#     score = (2. * K.sum(intersection) + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)
#     return 1. - score

# def bce_dice_loss(y_true, y_pred):
#     return binary_crossentropy(y_true, y_pred) + dice_loss(y_true, y_pred)

# def bce_logdice_loss(y_true, y_pred):
#     return binary_crossentropy(y_true, y_pred) - K.log(1. - dice_loss(y_true, y_pred))

# def weighted_bce_loss(y_true, y_pred, weight):
#     epsilon = 1e-7
#     y_pred = K.clip(y_pred, epsilon, 1. - epsilon)
#     logit_y_pred = K.log(y_pred / (1. - y_pred))
#     loss = weight * (logit_y_pred * (1. - y_true) + 
#                      K.log(1. + K.exp(-K.abs(logit_y_pred))) + K.maximum(-logit_y_pred, 0.))
#     return K.sum(loss) / K.sum(weight)

# def weighted_dice_loss(y_true, y_pred, weight):
#     smooth = 1.
#     w, m1, m2 = weight, y_true, y_pred
#     intersection = (m1 * m2)
#     score = (2. * K.sum(w * intersection) + smooth) / (K.sum(w * m1) + K.sum(w * m2) + smooth)
#     loss = 1. - K.sum(score)
#     return loss

# def weighted_bce_dice_loss(y_true, y_pred):
#     y_true = K.cast(y_true, 'float32')
#     y_pred = K.cast(y_pred, 'float32')
#     # if we want to get same size of output, kernel size must be odd
#     averaged_mask = K.pool2d(
#             y_true, pool_size=(50, 50), strides=(1, 1), padding='same', pool_mode='avg')
#     weight = K.ones_like(averaged_mask)
#     w0 = K.sum(weight)
#     weight = 5. * K.exp(-5. * K.abs(averaged_mask - 0.5))
#     w1 = K.sum(weight)
#     weight *= (w0 / w1)
#     loss = weighted_bce_loss(y_true, y_pred, weight) + dice_loss(y_true, y_pred)
#     return loss
  
# def focal_loss(gamma=2., alpha=.25):
#     def focal_loss_fixed(y_true, y_pred):
#         pt_1 = tf.where(tf.equal(y_true, 1), y_pred, tf.ones_like(y_pred))
#         pt_0 = tf.where(tf.equal(y_true, 0), y_pred, tf.zeros_like(y_pred))
#         return -K.sum(alpha * K.pow(1. - pt_1, gamma) * K.log(pt_1))-K.sum((1-alpha) * K.pow( pt_0, gamma) * K.log(1. - pt_0))
#     return focal_loss_fixed

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, 256, 256, 3)  9           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 262, 262, 3)  0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, 128, 128, 64) 9408        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, 128, 128, 64) 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, 128, 128, 64) 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 130, 130, 64) 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, 64, 64, 64)   0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, 64, 64, 64)   256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, 64, 64, 64)   0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, 64, 64, 64)   4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, 64, 64, 64)   0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 66, 66, 64)   0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, 64, 64, 64)   36864       zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn3 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu3 (Activation) (None, 64, 64, 64)   0           stage1_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv3 (Conv2D)     (None, 64, 64, 256)  16384       stage1_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, 64, 64, 256)  16384       stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 64, 256)  0           stage1_unit1_conv3[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, 64, 64, 256)  1024        add_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, 64, 64, 256)  0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, 64, 64, 64)   16384       stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, 64, 64, 64)   0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 66, 66, 64)   0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, 64, 64, 64)   36864       zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn3 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu3 (Activation) (None, 64, 64, 64)   0           stage1_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv3 (Conv2D)     (None, 64, 64, 256)  16384       stage1_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 64, 64, 256)  0           stage1_unit2_conv3[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn1 (BatchNormaliz (None, 64, 64, 256)  1024        add_2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu1 (Activation) (None, 64, 64, 256)  0           stage1_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv1 (Conv2D)     (None, 64, 64, 64)   16384       stage1_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn2 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu2 (Activation) (None, 64, 64, 64)   0           stage1_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 66, 66, 64)   0           stage1_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv2 (Conv2D)     (None, 64, 64, 64)   36864       zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn3 (BatchNormaliz (None, 64, 64, 64)   256         stage1_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu3 (Activation) (None, 64, 64, 64)   0           stage1_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv3 (Conv2D)     (None, 64, 64, 256)  16384       stage1_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 64, 64, 256)  0           stage1_unit3_conv3[0][0]
#                                                                  add_2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, 64, 64, 256)  1024        add_3[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, 64, 64, 256)  0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, 64, 64, 128)  32768       stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, 64, 64, 128)  512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, 64, 64, 128)  0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 66, 66, 128)  0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn3 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu3 (Activation) (None, 32, 32, 128)  0           stage2_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv3 (Conv2D)     (None, 32, 32, 512)  65536       stage2_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, 32, 32, 512)  131072      stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 32, 32, 512)  0           stage2_unit1_conv3[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, 32, 32, 512)  2048        add_4[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, 32, 32, 512)  0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, 32, 32, 128)  65536       stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, 32, 32, 128)  0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 34, 34, 128)  0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_7[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn3 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu3 (Activation) (None, 32, 32, 128)  0           stage2_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv3 (Conv2D)     (None, 32, 32, 512)  65536       stage2_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 512)  0           stage2_unit2_conv3[0][0]
#                                                                  add_4[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn1 (BatchNormaliz (None, 32, 32, 512)  2048        add_5[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu1 (Activation) (None, 32, 32, 512)  0           stage2_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv1 (Conv2D)     (None, 32, 32, 128)  65536       stage2_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn2 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu2 (Activation) (None, 32, 32, 128)  0           stage2_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 34, 34, 128)  0           stage2_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv2 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn3 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu3 (Activation) (None, 32, 32, 128)  0           stage2_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv3 (Conv2D)     (None, 32, 32, 512)  65536       stage2_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 32, 32, 512)  0           stage2_unit3_conv3[0][0]
#                                                                  add_5[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn1 (BatchNormaliz (None, 32, 32, 512)  2048        add_6[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu1 (Activation) (None, 32, 32, 512)  0           stage2_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv1 (Conv2D)     (None, 32, 32, 128)  65536       stage2_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn2 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu2 (Activation) (None, 32, 32, 128)  0           stage2_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 34, 34, 128)  0           stage2_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv2 (Conv2D)     (None, 32, 32, 128)  147456      zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn3 (BatchNormaliz (None, 32, 32, 128)  512         stage2_unit4_conv2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu3 (Activation) (None, 32, 32, 128)  0           stage2_unit4_bn3[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv3 (Conv2D)     (None, 32, 32, 512)  65536       stage2_unit4_relu3[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 32, 32, 512)  0           stage2_unit4_conv3[0][0]
#                                                                  add_6[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, 32, 32, 512)  2048        add_7[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, 32, 32, 512)  0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, 32, 32, 256)  131072      stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, 32, 32, 256)  1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, 32, 32, 256)  0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 34, 34, 256)  0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn3 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu3 (Activation) (None, 16, 16, 256)  0           stage3_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv3 (Conv2D)     (None, 16, 16, 1024) 262144      stage3_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, 16, 16, 1024) 524288      stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 16, 16, 1024) 0           stage3_unit1_conv3[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, 16, 16, 1024) 4096        add_8[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, 16, 16, 1024) 0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, 16, 16, 256)  262144      stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn3 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu3 (Activation) (None, 16, 16, 256)  0           stage3_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv3 (Conv2D)     (None, 16, 16, 1024) 262144      stage3_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 16, 16, 1024) 0           stage3_unit2_conv3[0][0]
#                                                                  add_8[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn1 (BatchNormaliz (None, 16, 16, 1024) 4096        add_9[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu1 (Activation) (None, 16, 16, 1024) 0           stage3_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv1 (Conv2D)     (None, 16, 16, 256)  262144      stage3_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn3 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu3 (Activation) (None, 16, 16, 256)  0           stage3_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv3 (Conv2D)     (None, 16, 16, 1024) 262144      stage3_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 16, 16, 1024) 0           stage3_unit3_conv3[0][0]
#                                                                  add_9[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn1 (BatchNormaliz (None, 16, 16, 1024) 4096        add_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu1 (Activation) (None, 16, 16, 1024) 0           stage3_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv1 (Conv2D)     (None, 16, 16, 256)  262144      stage3_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn3 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit4_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu3 (Activation) (None, 16, 16, 256)  0           stage3_unit4_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv3 (Conv2D)     (None, 16, 16, 1024) 262144      stage3_unit4_relu3[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 16, 16, 1024) 0           stage3_unit4_conv3[0][0]
#                                                                  add_10[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn1 (BatchNormaliz (None, 16, 16, 1024) 4096        add_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu1 (Activation) (None, 16, 16, 1024) 0           stage3_unit5_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv1 (Conv2D)     (None, 16, 16, 256)  262144      stage3_unit5_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit5_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit5_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn3 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit5_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu3 (Activation) (None, 16, 16, 256)  0           stage3_unit5_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv3 (Conv2D)     (None, 16, 16, 1024) 262144      stage3_unit5_relu3[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 16, 16, 1024) 0           stage3_unit5_conv3[0][0]
#                                                                  add_11[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn1 (BatchNormaliz (None, 16, 16, 1024) 4096        add_12[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu1 (Activation) (None, 16, 16, 1024) 0           stage3_unit6_bn1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv1 (Conv2D)     (None, 16, 16, 256)  262144      stage3_unit6_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn2 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit6_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu2 (Activation) (None, 16, 16, 256)  0           stage3_unit6_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 18, 18, 256)  0           stage3_unit6_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv2 (Conv2D)     (None, 16, 16, 256)  589824      zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn3 (BatchNormaliz (None, 16, 16, 256)  1024        stage3_unit6_conv2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu3 (Activation) (None, 16, 16, 256)  0           stage3_unit6_bn3[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv3 (Conv2D)     (None, 16, 16, 1024) 262144      stage3_unit6_relu3[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 16, 16, 1024) 0           stage3_unit6_conv3[0][0]
#                                                                  add_12[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, 16, 16, 1024) 4096        add_13[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, 16, 16, 1024) 0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, 16, 16, 512)  524288      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, 16, 16, 512)  2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, 16, 16, 512)  0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 18, 18, 512)  0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, 8, 8, 512)    2359296     zero_padding2d_16[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn3 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit1_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu3 (Activation) (None, 8, 8, 512)    0           stage4_unit1_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv3 (Conv2D)     (None, 8, 8, 2048)   1048576     stage4_unit1_relu3[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, 8, 8, 2048)   2097152     stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 8, 8, 2048)   0           stage4_unit1_conv3[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, 8, 8, 2048)   8192        add_14[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, 8, 8, 2048)   0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, 8, 8, 512)    1048576     stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, 8, 8, 512)    0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 10, 10, 512)  0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, 8, 8, 512)    2359296     zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn3 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit2_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu3 (Activation) (None, 8, 8, 512)    0           stage4_unit2_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv3 (Conv2D)     (None, 8, 8, 2048)   1048576     stage4_unit2_relu3[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 8, 8, 2048)   0           stage4_unit2_conv3[0][0]
#                                                                  add_14[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn1 (BatchNormaliz (None, 8, 8, 2048)   8192        add_15[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu1 (Activation) (None, 8, 8, 2048)   0           stage4_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv1 (Conv2D)     (None, 8, 8, 512)    1048576     stage4_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn2 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu2 (Activation) (None, 8, 8, 512)    0           stage4_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 10, 10, 512)  0           stage4_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv2 (Conv2D)     (None, 8, 8, 512)    2359296     zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn3 (BatchNormaliz (None, 8, 8, 512)    2048        stage4_unit3_conv2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu3 (Activation) (None, 8, 8, 512)    0           stage4_unit3_bn3[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv3 (Conv2D)     (None, 8, 8, 2048)   1048576     stage4_unit3_relu3[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 8, 8, 2048)   0           stage4_unit3_conv3[0][0]
#                                                                  add_15[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 8, 8, 2048)   8192        add_16[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, 8, 8, 2048)   0           bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsample (UpSamp (None, 16, 16, 2048) 0           relu1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 3072) 0           decoder_stage0_upsample[0][0]
#                                                                  stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_conv1 (Conv2D)   (None, 16, 16, 256)  7078144     concatenate_1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_relu1 (Activatio (None, 16, 16, 256)  0           decoder_stage0_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_conv2 (Conv2D)   (None, 16, 16, 256)  590080      decoder_stage0_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_relu2 (Activatio (None, 16, 16, 256)  0           decoder_stage0_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsample (UpSamp (None, 32, 32, 256)  0           decoder_stage0_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 768)  0           decoder_stage1_upsample[0][0]
#                                                                  stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_conv1 (Conv2D)   (None, 32, 32, 128)  884864      concatenate_2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_relu1 (Activatio (None, 32, 32, 128)  0           decoder_stage1_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_conv2 (Conv2D)   (None, 32, 32, 128)  147584      decoder_stage1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_relu2 (Activatio (None, 32, 32, 128)  0           decoder_stage1_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsample (UpSamp (None, 64, 64, 128)  0           decoder_stage1_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 384)  0           decoder_stage2_upsample[0][0]
#                                                                  stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_conv1 (Conv2D)   (None, 64, 64, 64)   221248      concatenate_3[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_relu1 (Activatio (None, 64, 64, 64)   0           decoder_stage2_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_conv2 (Conv2D)   (None, 64, 64, 64)   36928       decoder_stage2_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_relu2 (Activatio (None, 64, 64, 64)   0           decoder_stage2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsample (UpSamp (None, 128, 128, 64) 0           decoder_stage2_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 128, 128, 128 0           decoder_stage3_upsample[0][0]
#                                                                  relu0[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_conv1 (Conv2D)   (None, 128, 128, 32) 36896       concatenate_4[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_relu1 (Activatio (None, 128, 128, 32) 0           decoder_stage3_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_conv2 (Conv2D)   (None, 128, 128, 32) 9248        decoder_stage3_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_relu2 (Activatio (None, 128, 128, 32) 0           decoder_stage3_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsample (UpSamp (None, 256, 256, 32) 0           decoder_stage3_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_conv1 (Conv2D)   (None, 256, 256, 16) 4624        decoder_stage4_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_relu1 (Activatio (None, 256, 256, 16) 0           decoder_stage4_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_conv2 (Conv2D)   (None, 256, 256, 16) 2320        decoder_stage4_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_relu2 (Activatio (None, 256, 256, 16) 0           decoder_stage4_conv2[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, 256, 256, 1)  145         decoder_stage4_relu2[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, 256, 256, 1)  0           final_conv[0][0]
# ==================================================================================================
# Total params: 32,558,138
# Trainable params: 32,512,564
# Non-trainable params: 45,574
# __________________________________________________________________________________________________

# %%
model.compile(optimizer = 'adam' , loss = 'binary_crossentropy' , metrics = [mean_iou , 'acc'])

# %%
lr_reducer = ReduceLROnPlateau(monitor = 'val_mean_iou' , factor = 0.5 , 
                               mode = 'max' , patience = 5 , verbose = 2 , min_delta = 0.01)
checkpointer = ModelCheckpoint('resnet50_unet_1998.h5', monitor='val_mean_iou', 
                               verbose=2, save_best_only=True , save_weights_only = False , mode = 'max')
early_stopper = EarlyStopping(monitor = 'val_mean_iou' , mode = 'max' , patience = 10)

# %%
results = model.fit_generator(train_gen , steps_per_epoch = 1125 , epochs = 100 ,
                              validation_data = val_gen , validation_steps = 25 ,
                              callbacks=[checkpointer , lr_reducer, early_stopper] , verbose = 1)
# Out:
# Epoch 1/100
# 1125/1125 [==============================] - 488s 434ms/step - loss: 0.2879 - mean_iou: 0.5336 - acc: 0.8844 - val_loss: 0.4839 - val_mean_iou: 0.5905 - val_acc: 0.7633
#
# Epoch 00001: val_mean_iou improved from -inf to 0.59052, saving model to resnet50_unet_1998.h5
# Epoch 2/100
# 1125/1125 [==============================] - 479s 426ms/step - loss: 0.2192 - mean_iou: 0.6222 - acc: 0.9151 - val_loss: 0.2461 - val_mean_iou: 0.6449 - val_acc: 0.9130
#
# Epoch 00002: val_mean_iou improved from 0.59052 to 0.64488, saving model to resnet50_unet_1998.h5
# Epoch 3/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.1949 - mean_iou: 0.6604 - acc: 0.9246 - val_loss: 0.2060 - val_mean_iou: 0.6761 - val_acc: 0.9213
#
# Epoch 00003: val_mean_iou improved from 0.64488 to 0.67608, saving model to resnet50_unet_1998.h5
# Epoch 4/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.1711 - mean_iou: 0.6893 - acc: 0.9328 - val_loss: 0.1736 - val_mean_iou: 0.7002 - val_acc: 0.9429
#
# Epoch 00004: val_mean_iou improved from 0.67608 to 0.70017, saving model to resnet50_unet_1998.h5
# Epoch 5/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.1600 - mean_iou: 0.7094 - acc: 0.9381 - val_loss: 0.2439 - val_mean_iou: 0.7174 - val_acc: 0.8960
#
# Epoch 00005: val_mean_iou improved from 0.70017 to 0.71745, saving model to resnet50_unet_1998.h5
# Epoch 6/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.1505 - mean_iou: 0.7242 - acc: 0.9412 - val_loss: 0.2754 - val_mean_iou: 0.7307 - val_acc: 0.9172
#
# Epoch 00006: val_mean_iou improved from 0.71745 to 0.73067, saving model to resnet50_unet_1998.h5
# Epoch 7/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.1442 - mean_iou: 0.7364 - acc: 0.9437 - val_loss: 0.2187 - val_mean_iou: 0.7415 - val_acc: 0.9143
#
# Epoch 00007: val_mean_iou improved from 0.73067 to 0.74154, saving model to resnet50_unet_1998.h5
# Epoch 8/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.1382 - mean_iou: 0.7459 - acc: 0.9452 - val_loss: 0.1781 - val_mean_iou: 0.7501 - val_acc: 0.9266
#
# Epoch 00008: val_mean_iou improved from 0.74154 to 0.75005, saving model to resnet50_unet_1998.h5
# Epoch 9/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.1348 - mean_iou: 0.7538 - acc: 0.9462 - val_loss: 0.1786 - val_mean_iou: 0.7572 - val_acc: 0.9288
#
# Epoch 00009: val_mean_iou improved from 0.75005 to 0.75721, saving model to resnet50_unet_1998.h5
# Epoch 10/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.1320 - mean_iou: 0.7602 - acc: 0.9479 - val_loss: 0.2096 - val_mean_iou: 0.7634 - val_acc: 0.9296
#
# Epoch 00010: val_mean_iou improved from 0.75721 to 0.76335, saving model to resnet50_unet_1998.h5
# Epoch 11/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.1276 - mean_iou: 0.7662 - acc: 0.9490 - val_loss: 0.1618 - val_mean_iou: 0.7689 - val_acc: 0.9391
#
# Epoch 00011: val_mean_iou improved from 0.76335 to 0.76894, saving model to resnet50_unet_1998.h5
# Epoch 12/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.1267 - mean_iou: 0.7713 - acc: 0.9500 - val_loss: 0.1754 - val_mean_iou: 0.7737 - val_acc: 0.9336
#
# Epoch 00012: val_mean_iou improved from 0.76894 to 0.77370, saving model to resnet50_unet_1998.h5
# Epoch 13/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.1211 - mean_iou: 0.7761 - acc: 0.9513 - val_loss: 0.1989 - val_mean_iou: 0.7783 - val_acc: 0.9230
#
# Epoch 00013: val_mean_iou improved from 0.77370 to 0.77830, saving model to resnet50_unet_1998.h5
# Epoch 14/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.1187 - mean_iou: 0.7804 - acc: 0.9527 - val_loss: 0.1780 - val_mean_iou: 0.7824 - val_acc: 0.9392
#
# Epoch 00014: val_mean_iou improved from 0.77830 to 0.78242, saving model to resnet50_unet_1998.h5
# Epoch 15/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.1156 - mean_iou: 0.7844 - acc: 0.9537 - val_loss: 0.1444 - val_mean_iou: 0.7863 - val_acc: 0.9468
#
# Epoch 00015: val_mean_iou improved from 0.78242 to 0.78633, saving model to resnet50_unet_1998.h5
# Epoch 16/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.1149 - mean_iou: 0.7881 - acc: 0.9541 - val_loss: 0.1834 - val_mean_iou: 0.7898 - val_acc: 0.9222
#
# Epoch 00016: val_mean_iou improved from 0.78633 to 0.78977, saving model to resnet50_unet_1998.h5
# Epoch 17/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.1136 - mean_iou: 0.7913 - acc: 0.9544 - val_loss: 0.1694 - val_mean_iou: 0.7929 - val_acc: 0.9319
#
# Epoch 00017: val_mean_iou improved from 0.78977 to 0.79289, saving model to resnet50_unet_1998.h5
# Epoch 18/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.1125 - mean_iou: 0.7944 - acc: 0.9551 - val_loss: 0.1981 - val_mean_iou: 0.7958 - val_acc: 0.9339
#
# Epoch 00018: val_mean_iou improved from 0.79289 to 0.79582, saving model to resnet50_unet_1998.h5
# Epoch 19/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.1080 - mean_iou: 0.7972 - acc: 0.9564 - val_loss: 0.1538 - val_mean_iou: 0.7986 - val_acc: 0.9386
#
# Epoch 00019: val_mean_iou improved from 0.79582 to 0.79855, saving model to resnet50_unet_1998.h5
# Epoch 20/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.1097 - mean_iou: 0.7997 - acc: 0.9555 - val_loss: 0.1740 - val_mean_iou: 0.8009 - val_acc: 0.9308
#
# Epoch 00020: val_mean_iou improved from 0.79855 to 0.80089, saving model to resnet50_unet_1998.h5
# Epoch 21/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.1069 - mean_iou: 0.8020 - acc: 0.9571 - val_loss: 0.1834 - val_mean_iou: 0.8032 - val_acc: 0.9402
#
# Epoch 00021: val_mean_iou improved from 0.80089 to 0.80320, saving model to resnet50_unet_1998.h5
# Epoch 22/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.1046 - mean_iou: 0.8043 - acc: 0.9575 - val_loss: 0.1747 - val_mean_iou: 0.8054 - val_acc: 0.9309
#
# Epoch 00022: val_mean_iou improved from 0.80320 to 0.80544, saving model to resnet50_unet_1998.h5
# Epoch 23/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.1030 - mean_iou: 0.8065 - acc: 0.9581 - val_loss: 0.1397 - val_mean_iou: 0.8075 - val_acc: 0.9440
#
# Epoch 00023: val_mean_iou improved from 0.80544 to 0.80754, saving model to resnet50_unet_1998.h5
# Epoch 24/100
# 1125/1125 [==============================] - 472s 420ms/step - loss: 0.1027 - mean_iou: 0.8085 - acc: 0.9585 - val_loss: 0.1483 - val_mean_iou: 0.8095 - val_acc: 0.9460
#
# Epoch 00024: val_mean_iou improved from 0.80754 to 0.80953, saving model to resnet50_unet_1998.h5
# Epoch 25/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.1003 - mean_iou: 0.8105 - acc: 0.9594 - val_loss: 0.1546 - val_mean_iou: 0.8115 - val_acc: 0.9403
#
# Epoch 00025: val_mean_iou improved from 0.80953 to 0.81149, saving model to resnet50_unet_1998.h5
# Epoch 26/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0994 - mean_iou: 0.8124 - acc: 0.9601 - val_loss: 0.1540 - val_mean_iou: 0.8134 - val_acc: 0.9419
#
# Epoch 00026: val_mean_iou improved from 0.81149 to 0.81339, saving model to resnet50_unet_1998.h5
# Epoch 27/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0989 - mean_iou: 0.8143 - acc: 0.9598 - val_loss: 0.1334 - val_mean_iou: 0.8152 - val_acc: 0.9493
#
# Epoch 00027: val_mean_iou improved from 0.81339 to 0.81519, saving model to resnet50_unet_1998.h5
# Epoch 28/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0970 - mean_iou: 0.8160 - acc: 0.9609 - val_loss: 0.1449 - val_mean_iou: 0.8169 - val_acc: 0.9420
#
# Epoch 00028: val_mean_iou improved from 0.81519 to 0.81690, saving model to resnet50_unet_1998.h5
# Epoch 29/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.0960 - mean_iou: 0.8177 - acc: 0.9608 - val_loss: 0.1323 - val_mean_iou: 0.8185 - val_acc: 0.9504
#
# Epoch 00029: val_mean_iou improved from 0.81690 to 0.81851, saving model to resnet50_unet_1998.h5
# Epoch 30/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.0953 - mean_iou: 0.8193 - acc: 0.9610 - val_loss: 0.1626 - val_mean_iou: 0.8201 - val_acc: 0.9387
#
# Epoch 00030: val_mean_iou improved from 0.81851 to 0.82007, saving model to resnet50_unet_1998.h5
# Epoch 31/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.0924 - mean_iou: 0.8209 - acc: 0.9625 - val_loss: 0.1515 - val_mean_iou: 0.8217 - val_acc: 0.9424
#
# Epoch 00031: val_mean_iou improved from 0.82007 to 0.82170, saving model to resnet50_unet_1998.h5
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# Epoch 32/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0798 - mean_iou: 0.8227 - acc: 0.9665 - val_loss: 0.1242 - val_mean_iou: 0.8237 - val_acc: 0.9488
#
# Epoch 00032: val_mean_iou improved from 0.82170 to 0.82368, saving model to resnet50_unet_1998.h5
# Epoch 33/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.0790 - mean_iou: 0.8247 - acc: 0.9668 - val_loss: 0.1754 - val_mean_iou: 0.8256 - val_acc: 0.9416
#
# Epoch 00033: val_mean_iou improved from 0.82368 to 0.82557, saving model to resnet50_unet_1998.h5
# Epoch 34/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.0782 - mean_iou: 0.8265 - acc: 0.9675 - val_loss: 0.1243 - val_mean_iou: 0.8274 - val_acc: 0.9518
#
# Epoch 00034: val_mean_iou improved from 0.82557 to 0.82743, saving model to resnet50_unet_1998.h5
# Epoch 35/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0768 - mean_iou: 0.8283 - acc: 0.9673 - val_loss: 0.1557 - val_mean_iou: 0.8292 - val_acc: 0.9507
#
# Epoch 00035: val_mean_iou improved from 0.82743 to 0.82920, saving model to resnet50_unet_1998.h5
# Epoch 36/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0761 - mean_iou: 0.8301 - acc: 0.9680 - val_loss: 0.1273 - val_mean_iou: 0.8309 - val_acc: 0.9502
#
# Epoch 00036: val_mean_iou improved from 0.82920 to 0.83090, saving model to resnet50_unet_1998.h5
# Epoch 37/100
# 1125/1125 [==============================] - 472s 420ms/step - loss: 0.0755 - mean_iou: 0.8317 - acc: 0.9683 - val_loss: 0.1719 - val_mean_iou: 0.8325 - val_acc: 0.9335
#
# Epoch 00037: val_mean_iou improved from 0.83090 to 0.83251, saving model to resnet50_unet_1998.h5
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# Epoch 38/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0669 - mean_iou: 0.8334 - acc: 0.9713 - val_loss: 0.1651 - val_mean_iou: 0.8343 - val_acc: 0.9502
#
# Epoch 00038: val_mean_iou improved from 0.83251 to 0.83432, saving model to resnet50_unet_1998.h5
# Epoch 39/100
# 1125/1125 [==============================] - 472s 420ms/step - loss: 0.0650 - mean_iou: 0.8352 - acc: 0.9719 - val_loss: 0.1233 - val_mean_iou: 0.8361 - val_acc: 0.9596
#
# Epoch 00039: val_mean_iou improved from 0.83432 to 0.83612, saving model to resnet50_unet_1998.h5
# Epoch 40/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0631 - mean_iou: 0.8370 - acc: 0.9726 - val_loss: 0.1450 - val_mean_iou: 0.8379 - val_acc: 0.9475
#
# Epoch 00040: val_mean_iou improved from 0.83612 to 0.83788, saving model to resnet50_unet_1998.h5
# Epoch 41/100
# 1125/1125 [==============================] - 471s 419ms/step - loss: 0.0621 - mean_iou: 0.8388 - acc: 0.9736 - val_loss: 0.1709 - val_mean_iou: 0.8396 - val_acc: 0.9479
#
# Epoch 00041: val_mean_iou improved from 0.83788 to 0.83964, saving model to resnet50_unet_1998.h5
# Epoch 42/100
# 1125/1125 [==============================] - 472s 419ms/step - loss: 0.0622 - mean_iou: 0.8404 - acc: 0.9731 - val_loss: 0.1513 - val_mean_iou: 0.8413 - val_acc: 0.9498
#
# Epoch 00042: val_mean_iou improved from 0.83964 to 0.84127, saving model to resnet50_unet_1998.h5
# Epoch 43/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0611 - mean_iou: 0.8420 - acc: 0.9736 - val_loss: 0.1706 - val_mean_iou: 0.8428 - val_acc: 0.9444
#
# Epoch 00043: val_mean_iou improved from 0.84127 to 0.84283, saving model to resnet50_unet_1998.h5
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# Epoch 44/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0570 - mean_iou: 0.8437 - acc: 0.9758 - val_loss: 0.1877 - val_mean_iou: 0.8445 - val_acc: 0.9439
#
# Epoch 00044: val_mean_iou improved from 0.84283 to 0.84452, saving model to resnet50_unet_1998.h5
# Epoch 45/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0549 - mean_iou: 0.8453 - acc: 0.9761 - val_loss: 0.1357 - val_mean_iou: 0.8462 - val_acc: 0.9566
#
# Epoch 00045: val_mean_iou improved from 0.84452 to 0.84615, saving model to resnet50_unet_1998.h5
# Epoch 46/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0561 - mean_iou: 0.8469 - acc: 0.9754 - val_loss: 0.1614 - val_mean_iou: 0.8477 - val_acc: 0.9484
#
# Epoch 00046: val_mean_iou improved from 0.84615 to 0.84768, saving model to resnet50_unet_1998.h5
# Epoch 47/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0537 - mean_iou: 0.8484 - acc: 0.9766 - val_loss: 0.1715 - val_mean_iou: 0.8492 - val_acc: 0.9477
#
# Epoch 00047: val_mean_iou improved from 0.84768 to 0.84921, saving model to resnet50_unet_1998.h5
# Epoch 48/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0532 - mean_iou: 0.8499 - acc: 0.9766 - val_loss: 0.1760 - val_mean_iou: 0.8507 - val_acc: 0.9506
#
# Epoch 00048: val_mean_iou improved from 0.84921 to 0.85067, saving model to resnet50_unet_1998.h5
# Epoch 49/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0531 - mean_iou: 0.8514 - acc: 0.9771 - val_loss: 0.1634 - val_mean_iou: 0.8521 - val_acc: 0.9506
#
# Epoch 00049: val_mean_iou improved from 0.85067 to 0.85211, saving model to resnet50_unet_1998.h5
#
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# Epoch 50/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0525 - mean_iou: 0.8528 - acc: 0.9770 - val_loss: 0.1267 - val_mean_iou: 0.8535 - val_acc: 0.9682
#
# Epoch 00050: val_mean_iou improved from 0.85211 to 0.85352, saving model to resnet50_unet_1998.h5
# Epoch 51/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0504 - mean_iou: 0.8542 - acc: 0.9777 - val_loss: 0.1696 - val_mean_iou: 0.8549 - val_acc: 0.9508
#
# Epoch 00051: val_mean_iou improved from 0.85352 to 0.85492, saving model to resnet50_unet_1998.h5
# Epoch 52/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0492 - mean_iou: 0.8556 - acc: 0.9783 - val_loss: 0.1371 - val_mean_iou: 0.8563 - val_acc: 0.9595
#
# Epoch 00052: val_mean_iou improved from 0.85492 to 0.85627, saving model to resnet50_unet_1998.h5
# Epoch 53/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0502 - mean_iou: 0.8569 - acc: 0.9778 - val_loss: 0.1942 - val_mean_iou: 0.8576 - val_acc: 0.9508
#
# Epoch 00053: val_mean_iou improved from 0.85627 to 0.85757, saving model to resnet50_unet_1998.h5
# Epoch 54/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0504 - mean_iou: 0.8582 - acc: 0.9778 - val_loss: 0.1901 - val_mean_iou: 0.8588 - val_acc: 0.9506
#
# Epoch 00054: val_mean_iou improved from 0.85757 to 0.85880, saving model to resnet50_unet_1998.h5
# Epoch 55/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0504 - mean_iou: 0.8594 - acc: 0.9777 - val_loss: 0.1501 - val_mean_iou: 0.8600 - val_acc: 0.9544
#
# Epoch 00055: val_mean_iou improved from 0.85880 to 0.85999, saving model to resnet50_unet_1998.h5
# Epoch 56/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0491 - mean_iou: 0.8606 - acc: 0.9783 - val_loss: 0.1823 - val_mean_iou: 0.8612 - val_acc: 0.9509
#
# Epoch 00056: val_mean_iou improved from 0.85999 to 0.86116, saving model to resnet50_unet_1998.h5
#
# Epoch 00056: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# Epoch 57/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.0481 - mean_iou: 0.8617 - acc: 0.9785 - val_loss: 0.1348 - val_mean_iou: 0.8623 - val_acc: 0.9581
#
# Epoch 00057: val_mean_iou improved from 0.86116 to 0.86233, saving model to resnet50_unet_1998.h5
# Epoch 58/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0498 - mean_iou: 0.8629 - acc: 0.9780 - val_loss: 0.1830 - val_mean_iou: 0.8634 - val_acc: 0.9530
#
# Epoch 00058: val_mean_iou improved from 0.86233 to 0.86341, saving model to resnet50_unet_1998.h5
# Epoch 59/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.0480 - mean_iou: 0.8640 - acc: 0.9785 - val_loss: 0.1737 - val_mean_iou: 0.8645 - val_acc: 0.9547
#
# Epoch 00059: val_mean_iou improved from 0.86341 to 0.86449, saving model to resnet50_unet_1998.h5
# Epoch 60/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0482 - mean_iou: 0.8650 - acc: 0.9786 - val_loss: 0.2315 - val_mean_iou: 0.8655 - val_acc: 0.9411
#
# Epoch 00060: val_mean_iou improved from 0.86449 to 0.86555, saving model to resnet50_unet_1998.h5
# Epoch 61/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0473 - mean_iou: 0.8660 - acc: 0.9788 - val_loss: 0.1752 - val_mean_iou: 0.8666 - val_acc: 0.9536
#
# Epoch 00061: val_mean_iou improved from 0.86555 to 0.86656, saving model to resnet50_unet_1998.h5
# Epoch 62/100
# 1125/1125 [==============================] - 475s 422ms/step - loss: 0.0489 - mean_iou: 0.8670 - acc: 0.9784 - val_loss: 0.1616 - val_mean_iou: 0.8675 - val_acc: 0.9550
#
# Epoch 00062: val_mean_iou improved from 0.86656 to 0.86752, saving model to resnet50_unet_1998.h5
# Epoch 63/100
# 1125/1125 [==============================] - 474s 422ms/step - loss: 0.0478 - mean_iou: 0.8680 - acc: 0.9786 - val_loss: 0.1898 - val_mean_iou: 0.8685 - val_acc: 0.9481
#
# Epoch 00063: val_mean_iou improved from 0.86752 to 0.86847, saving model to resnet50_unet_1998.h5
# Epoch 64/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0464 - mean_iou: 0.8689 - acc: 0.9793 - val_loss: 0.2171 - val_mean_iou: 0.8694 - val_acc: 0.9496
#
# Epoch 00064: val_mean_iou improved from 0.86847 to 0.86942, saving model to resnet50_unet_1998.h5
# Epoch 65/100
# 1125/1125 [==============================] - 477s 424ms/step - loss: 0.0471 - mean_iou: 0.8699 - acc: 0.9788 - val_loss: 0.1881 - val_mean_iou: 0.8703 - val_acc: 0.9541
#
# Epoch 00065: val_mean_iou improved from 0.86942 to 0.87034, saving model to resnet50_unet_1998.h5
#
# Epoch 00065: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# Epoch 66/100
# 1125/1125 [==============================] - 476s 423ms/step - loss: 0.0471 - mean_iou: 0.8708 - acc: 0.9788 - val_loss: 0.1756 - val_mean_iou: 0.8712 - val_acc: 0.9535
#
# Epoch 00066: val_mean_iou improved from 0.87034 to 0.87121, saving model to resnet50_unet_1998.h5
# Epoch 67/100
# 1125/1125 [==============================] - 476s 423ms/step - loss: 0.0464 - mean_iou: 0.8716 - acc: 0.9792 - val_loss: 0.1653 - val_mean_iou: 0.8721 - val_acc: 0.9568
#
# Epoch 00067: val_mean_iou improved from 0.87121 to 0.87208, saving model to resnet50_unet_1998.h5
# Epoch 68/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0458 - mean_iou: 0.8725 - acc: 0.9796 - val_loss: 0.1645 - val_mean_iou: 0.8729 - val_acc: 0.9555
#
# Epoch 00068: val_mean_iou improved from 0.87208 to 0.87295, saving model to resnet50_unet_1998.h5
# Epoch 69/100
# 1125/1125 [==============================] - 472s 420ms/step - loss: 0.0455 - mean_iou: 0.8734 - acc: 0.9797 - val_loss: 0.1406 - val_mean_iou: 0.8738 - val_acc: 0.9579
#
# Epoch 00069: val_mean_iou improved from 0.87295 to 0.87379, saving model to resnet50_unet_1998.h5
# Epoch 70/100
# 1125/1125 [==============================] - 475s 422ms/step - loss: 0.0474 - mean_iou: 0.8742 - acc: 0.9789 - val_loss: 0.1558 - val_mean_iou: 0.8746 - val_acc: 0.9544
#
# Epoch 00070: val_mean_iou improved from 0.87379 to 0.87458, saving model to resnet50_unet_1998.h5
#
# Epoch 00070: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# Epoch 71/100
# 1125/1125 [==============================] - 475s 422ms/step - loss: 0.0464 - mean_iou: 0.8750 - acc: 0.9792 - val_loss: 0.1751 - val_mean_iou: 0.8754 - val_acc: 0.9527
#
# Epoch 00071: val_mean_iou improved from 0.87458 to 0.87536, saving model to resnet50_unet_1998.h5
# Epoch 72/100
# 1125/1125 [==============================] - 475s 422ms/step - loss: 0.0465 - mean_iou: 0.8757 - acc: 0.9791 - val_loss: 0.1683 - val_mean_iou: 0.8761 - val_acc: 0.9547
#
# Epoch 00072: val_mean_iou improved from 0.87536 to 0.87611, saving model to resnet50_unet_1998.h5
# Epoch 73/100
# 1125/1125 [==============================] - 475s 422ms/step - loss: 0.0459 - mean_iou: 0.8765 - acc: 0.9795 - val_loss: 0.1261 - val_mean_iou: 0.8769 - val_acc: 0.9604
#
# Epoch 00073: val_mean_iou improved from 0.87611 to 0.87685, saving model to resnet50_unet_1998.h5
# Epoch 74/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0460 - mean_iou: 0.8772 - acc: 0.9794 - val_loss: 0.1830 - val_mean_iou: 0.8776 - val_acc: 0.9537
#
# Epoch 00074: val_mean_iou improved from 0.87685 to 0.87757, saving model to resnet50_unet_1998.h5
# Epoch 75/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0452 - mean_iou: 0.8779 - acc: 0.9799 - val_loss: 0.1890 - val_mean_iou: 0.8783 - val_acc: 0.9496
#
# Epoch 00075: val_mean_iou improved from 0.87757 to 0.87828, saving model to resnet50_unet_1998.h5
# Epoch 76/100
# 1125/1125 [==============================] - 475s 422ms/step - loss: 0.0468 - mean_iou: 0.8786 - acc: 0.9791 - val_loss: 0.1798 - val_mean_iou: 0.8790 - val_acc: 0.9529
#
# Epoch 00076: val_mean_iou improved from 0.87828 to 0.87895, saving model to resnet50_unet_1998.h5
# Epoch 77/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0459 - mean_iou: 0.8793 - acc: 0.9795 - val_loss: 0.2141 - val_mean_iou: 0.8796 - val_acc: 0.9470
#
# Epoch 00077: val_mean_iou improved from 0.87895 to 0.87962, saving model to resnet50_unet_1998.h5
#
# Epoch 00077: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# Epoch 78/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0450 - mean_iou: 0.8800 - acc: 0.9798 - val_loss: 0.1604 - val_mean_iou: 0.8803 - val_acc: 0.9538
#
# Epoch 00078: val_mean_iou improved from 0.87962 to 0.88029, saving model to resnet50_unet_1998.h5
# Epoch 79/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0460 - mean_iou: 0.8806 - acc: 0.9792 - val_loss: 0.2021 - val_mean_iou: 0.8809 - val_acc: 0.9512
#
# Epoch 00079: val_mean_iou improved from 0.88029 to 0.88092, saving model to resnet50_unet_1998.h5
# Epoch 80/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0461 - mean_iou: 0.8812 - acc: 0.9794 - val_loss: 0.1644 - val_mean_iou: 0.8815 - val_acc: 0.9539
#
# Epoch 00080: val_mean_iou improved from 0.88092 to 0.88154, saving model to resnet50_unet_1998.h5
# Epoch 81/100
# 1125/1125 [==============================] - 475s 422ms/step - loss: 0.0454 - mean_iou: 0.8818 - acc: 0.9795 - val_loss: 0.1799 - val_mean_iou: 0.8822 - val_acc: 0.9523
#
# Epoch 00081: val_mean_iou improved from 0.88154 to 0.88215, saving model to resnet50_unet_1998.h5
# Epoch 82/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0454 - mean_iou: 0.8825 - acc: 0.9799 - val_loss: 0.1656 - val_mean_iou: 0.8828 - val_acc: 0.9557
#
# Epoch 00082: val_mean_iou improved from 0.88215 to 0.88276, saving model to resnet50_unet_1998.h5
#
# Epoch 00082: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# Epoch 83/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0458 - mean_iou: 0.8830 - acc: 0.9797 - val_loss: 0.2010 - val_mean_iou: 0.8833 - val_acc: 0.9510
#
# Epoch 00083: val_mean_iou improved from 0.88276 to 0.88334, saving model to resnet50_unet_1998.h5
# Epoch 84/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0453 - mean_iou: 0.8836 - acc: 0.9797 - val_loss: 0.1754 - val_mean_iou: 0.8839 - val_acc: 0.9512
#
# Epoch 00084: val_mean_iou improved from 0.88334 to 0.88391, saving model to resnet50_unet_1998.h5
# Epoch 85/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0446 - mean_iou: 0.8842 - acc: 0.9800 - val_loss: 0.1591 - val_mean_iou: 0.8845 - val_acc: 0.9548
#
# Epoch 00085: val_mean_iou improved from 0.88391 to 0.88447, saving model to resnet50_unet_1998.h5
# Epoch 86/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0455 - mean_iou: 0.8847 - acc: 0.9796 - val_loss: 0.1795 - val_mean_iou: 0.8850 - val_acc: 0.9525
#
# Epoch 00086: val_mean_iou improved from 0.88447 to 0.88501, saving model to resnet50_unet_1998.h5
# Epoch 87/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0455 - mean_iou: 0.8853 - acc: 0.9798 - val_loss: 0.1462 - val_mean_iou: 0.8856 - val_acc: 0.9593
#
# Epoch 00087: val_mean_iou improved from 0.88501 to 0.88555, saving model to resnet50_unet_1998.h5
#
# Epoch 00087: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# Epoch 88/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0465 - mean_iou: 0.8858 - acc: 0.9793 - val_loss: 0.1905 - val_mean_iou: 0.8861 - val_acc: 0.9479
#
# Epoch 00088: val_mean_iou improved from 0.88555 to 0.88607, saving model to resnet50_unet_1998.h5
# Epoch 89/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0448 - mean_iou: 0.8863 - acc: 0.9798 - val_loss: 0.1820 - val_mean_iou: 0.8866 - val_acc: 0.9510
#
# Epoch 00089: val_mean_iou improved from 0.88607 to 0.88658, saving model to resnet50_unet_1998.h5
# Epoch 90/100
# 1125/1125 [==============================] - 471s 419ms/step - loss: 0.0452 - mean_iou: 0.8868 - acc: 0.9799 - val_loss: 0.1917 - val_mean_iou: 0.8871 - val_acc: 0.9515
#
# Epoch 00090: val_mean_iou improved from 0.88658 to 0.88708, saving model to resnet50_unet_1998.h5
# Epoch 91/100
# 1125/1125 [==============================] - 472s 419ms/step - loss: 0.0445 - mean_iou: 0.8873 - acc: 0.9797 - val_loss: 0.1800 - val_mean_iou: 0.8876 - val_acc: 0.9524
#
# Epoch 00091: val_mean_iou improved from 0.88708 to 0.88757, saving model to resnet50_unet_1998.h5
# Epoch 92/100
# 1125/1125 [==============================] - 472s 420ms/step - loss: 0.0454 - mean_iou: 0.8878 - acc: 0.9796 - val_loss: 0.1795 - val_mean_iou: 0.8881 - val_acc: 0.9552
#
# Epoch 00092: val_mean_iou improved from 0.88757 to 0.88805, saving model to resnet50_unet_1998.h5
# Epoch 93/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0452 - mean_iou: 0.8883 - acc: 0.9798 - val_loss: 0.2104 - val_mean_iou: 0.8885 - val_acc: 0.9484
#
# Epoch 00093: val_mean_iou improved from 0.88805 to 0.88853, saving model to resnet50_unet_1998.h5
# Epoch 94/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0447 - mean_iou: 0.8888 - acc: 0.9797 - val_loss: 0.1753 - val_mean_iou: 0.8890 - val_acc: 0.9519
#
# Epoch 00094: val_mean_iou improved from 0.88853 to 0.88898, saving model to resnet50_unet_1998.h5
#
# Epoch 00094: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# Epoch 95/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0453 - mean_iou: 0.8892 - acc: 0.9800 - val_loss: 0.1836 - val_mean_iou: 0.8894 - val_acc: 0.9529
#
# Epoch 00095: val_mean_iou improved from 0.88898 to 0.88942, saving model to resnet50_unet_1998.h5
# Epoch 96/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0446 - mean_iou: 0.8896 - acc: 0.9799 - val_loss: 0.1808 - val_mean_iou: 0.8899 - val_acc: 0.9524
#
# Epoch 00096: val_mean_iou improved from 0.88942 to 0.88987, saving model to resnet50_unet_1998.h5
# Epoch 97/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0450 - mean_iou: 0.8901 - acc: 0.9798 - val_loss: 0.1114 - val_mean_iou: 0.8903 - val_acc: 0.9667
#
# Epoch 00097: val_mean_iou improved from 0.88987 to 0.89030, saving model to resnet50_unet_1998.h5
# Epoch 98/100
# 1125/1125 [==============================] - 474s 421ms/step - loss: 0.0458 - mean_iou: 0.8905 - acc: 0.9795 - val_loss: 0.2010 - val_mean_iou: 0.8907 - val_acc: 0.9507
#
# Epoch 00098: val_mean_iou improved from 0.89030 to 0.89072, saving model to resnet50_unet_1998.h5
# Epoch 99/100
# 1125/1125 [==============================] - 473s 420ms/step - loss: 0.0461 - mean_iou: 0.8909 - acc: 0.9792 - val_loss: 0.2036 - val_mean_iou: 0.8911 - val_acc: 0.9492
#
# Epoch 00099: val_mean_iou improved from 0.89072 to 0.89112, saving model to resnet50_unet_1998.h5
#
# Epoch 00099: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# Epoch 100/100
# 1125/1125 [==============================] - 473s 421ms/step - loss: 0.0451 - mean_iou: 0.8913 - acc: 0.9800 - val_loss: 0.1833 - val_mean_iou: 0.8915 - val_acc: 0.9530
#
# Epoch 00100: val_mean_iou improved from 0.89112 to 0.89152, saving model to resnet50_unet_1998.h5

# %%
X_test = np.zeros((len(test_ids), im_height, im_width, im_chan), dtype=np.uint8)
print('Getting and resizing test images ... ')
sys.stdout.flush()
for n, id_ in enumerate(test_ids):
    path = path_test
    img = load_img(path + '/images/' + id_)
    x = img_to_array(img)[:,:,1]
    x = resize(x, (256, 256, 3) , preserve_range=True)
    X_test[n] = x

print('Done!')
# Out:
# Getting and resizing test images ...
# C:\Program Files (x86)\Microsoft Visual Studio\Shared\Anaconda3_64\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# Done!

# %%
model = load_model("resnet50_unet_1998.h5" , custom_objects = {'mean_iou' : mean_iou})

# %%
preds_val = model.predict(X_val, verbose=1 , batch_size = 2)
preds_test = model.predict(X_test , verbose = 1 , batch_size = 2)

preds_val_t = (preds_val > 0.5).astype(np.uint8)
# Out:
# 400/400 [==============================] - 11s 29ms/step
# 18000/18000 [==============================] - 246s 14ms/step

# %%
model.evaluate(X_val , Y_val , verbose = 1)
# Out:
# 400/400 [==============================] - 10s 24ms/step
# [0.18081942945718765, 0.7849473404884338, 0.9524975204467774]

# %%
preds_test_upsampled = []
for i in range(len(preds_test)):
    preds_test_upsampled.append(resize(np.squeeze(preds_test[i]), 
                                       (101, 101), 
                                       mode='constant', preserve_range=True))

# %%
def iou_metric(y_true_in, y_pred_in, print_table=False):
    
    labels = y_true_in
    y_pred = y_pred_in
    
    true_objects = 2
    pred_objects = 2

    intersection = np.histogram2d(labels.flatten(), y_pred.flatten(), bins=(true_objects, pred_objects))[0]

    area_true = np.histogram(labels, bins = true_objects)[0]
    area_pred = np.histogram(y_pred, bins = pred_objects)[0]
    area_true = np.expand_dims(area_true, -1)
    area_pred = np.expand_dims(area_pred, 0)
    
    union = area_true + area_pred - intersection

    intersection = intersection[1:,1:]
    union = union[1:,1:]
    union[union == 0] = 1e-9

    iou = intersection / union

    def precision_at(threshold, iou):
        matches = iou > threshold
        true_positives = np.sum(matches, axis=1) == 1   # Correct objects
        false_positives = np.sum(matches, axis=0) == 0  # Missed objects
        false_negatives = np.sum(matches, axis=1) == 0  # Extra objects
        tp, fp, fn = np.sum(true_positives), np.sum(false_positives), np.sum(false_negatives)
        return tp, fp, fn

    prec = []
    if print_table:
        print("Thresh\tTP\tFP\tFN\tPrec.")
    for t in np.arange(0.5, 1.0, 0.05):
        tp, fp, fn = precision_at(t, iou)
        if (tp + fp + fn) > 0:
            p = tp / (tp + fp + fn)
        else:
            p = 0
        if print_table:
            print("{:1.3f}\t{}\t{}\t{}\t{:1.3f}".format(t, tp, fp, fn, p))
        prec.append(p)
    
    if print_table:
        print("AP\t-\t-\t-\t{:1.3f}".format(np.mean(prec)))
    return np.mean(prec)

def iou_metric_batch(y_true_in, y_pred_in):
    batch_size = y_true_in.shape[0]
    metric = []
    for batch in range(batch_size):
        value = iou_metric(y_true_in[batch], y_pred_in[batch])
        metric.append(value)
    return np.mean(metric)

# %%
thres = np.linspace(0.25, 0.75, 20)
thres_ioc = [iou_metric_batch(Y_val, np.int32(preds_val > t)) for t in thres]

# %%
plt.plot(thres, thres_ioc)

# %%
best_thres = thres[np.argmax(thres_ioc)]
best_thres, max(thres_ioc)
# Out:
# (0.6447368421052632, 0.77375)

# %%
def RLenc(img, order='F', format=True):
    """
    img is binary mask image, shape (r,c)
    order is down-then-right, i.e. Fortran
    format determines if the order needs to be preformatted (according to submission rules) or not

    returns run length as an array or string (if format is True)
    """
    bytes = img.reshape(img.shape[0] * img.shape[1], order=order)
    runs = []  ## list of run lengths
    r = 0  ## the current run length
    pos = 1  ## count starts from 1 per WK
    for c in bytes:
        if (c == 0):
            if r != 0:
                runs.append((pos, r))
                pos += r
                r = 0
            pos += 1
        else:
            r += 1

    # if last run is unsaved (i.e. data ends with 1)
    if r != 0:
        runs.append((pos, r))
        pos += r
        r = 0

    if format:
        z = ''

        for rr in runs:
            z += '{} {} '.format(rr[0], rr[1])
        return z[:-1]
    else:
        return runs

pred_dict = {fn[:-4]:RLenc(np.round(preds_test_upsampled[i] > best_thres)) for i,fn in enumerate(test_ids)}

# %%
sub = pd.DataFrame.from_dict(pred_dict,orient='index')
sub.index.names = ['id']
sub.columns = ['rle_mask']
sub.to_csv('submission.csv')

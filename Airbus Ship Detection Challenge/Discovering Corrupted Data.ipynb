# %%
import os
import numpy as np
import pandas as pd 
from skimage.io import imread
import matplotlib.pyplot as plt
from skimage.segmentation import mark_boundaries
from skimage.util.montage import montage2d as montage
% matplotlib inline

import gc; gc.enable()

from skimage.morphology import label
from sklearn.model_selection import train_test_split

from tqdm import tqdm_notebook
from skimage.morphology import binary_opening, disk

# %%
masks = pd.read_csv(os.path.join('data/','train_ship_segmentations.csv'))
print(masks.shape[0], 'masks found')
print(masks['ImageId'].value_counts().shape[0])
masks
# Out:
# 131030 masks found
# 104070
#               ImageId                                      EncodedPixels
# 0       00003e153.jpg                                                NaN
# 1       000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...
# 2       00021ddc3.jpg  101361 1 102128 3 102896 4 103663 6 104430 9 1...
# 3       00021ddc3.jpg  95225 2 95992 5 96760 7 97527 9 98294 9 99062 ...
# 4       00021ddc3.jpg  74444 4 75212 4 75980 4 76748 4 77517 3 78285 ...
# 5       00021ddc3.jpg  150423 2 151190 3 151958 3 152726 4 153495 3 1...
# 6       00021ddc3.jpg  139644 2 140408 6 141174 9 141942 9 142711 6 1...
# 7       00021ddc3.jpg  86727 2 87493 4 88261 4 89030 3 89798 4 90566 ...
# 8       00021ddc3.jpg  74441 3 75207 5 75975 5 76743 5 77511 5 78280 ...
# 9       00021ddc3.jpg  75972 3 76738 5 77506 5 78274 5 79042 6 79811 ...
# 10      00021ddc3.jpg  108287 1 109054 3 109821 4 110588 5 111356 5 1...
# ...

# %%
for img_id in masks['ImageId']:
    
    try:
        img = imread(os.path.join('data/train/', img_id))
    except:
        print(img_id, ' is corrupted')
# Out:
# 0552324fc.jpg  is corrupted
# 0fa0f283b.jpg  is corrupted
# 1721f5d2f.jpg  is corrupted
# 19adb3430.jpg  is corrupted
# 1bd1a35f6.jpg  is corrupted
# 2970e5fac.jpg  is corrupted
# 2ef15c9bb.jpg  is corrupted
# 33f23291f.jpg  is corrupted
# 37c7570c5.jpg  is corrupted
# 57e16a167.jpg  is corrupted
# 58186b23e.jpg  is corrupted
# 6384c3e78.jpg  is corrupted
# 671dcc95e.jpg  is corrupted
# 6acde7f3a.jpg  is corrupted
# 6b58c81c9.jpg  is corrupted
# 6e885a2ab.jpg  is corrupted
# 70676c5d1.jpg  is corrupted
# 715178de9.jpg  is corrupted
# 73841a7bf.jpg  is corrupted
# 74f845670.jpg  is corrupted
# 7b00823e7.jpg  is corrupted
# 8b0848a92.jpg  is corrupted
# 8cc0e15aa.jpg  is corrupted
# 924316212.jpg  is corrupted
# 93753d52a.jpg  is corrupted
# 9977ffbdc.jpg  is corrupted
# 9ea449c26.jpg  is corrupted
# ac43fcc09.jpg  is corrupted
# bcece24b7.jpg  is corrupted
# bd6efec1e.jpg  is corrupted
# bdd35b0e7.jpg  is corrupted
# d3730fd2d.jpg  is corrupted
# d63d8b257.jpg  is corrupted
# ...

# %%
for img_id in os.listdir("data/test"):
    
    try:
        img = imread(os.path.join('data/test/', img_id))
    except:
        print(img_id, ' is corrupted')
